# %%
import geopandas as gpd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import networkx as nx
import osmnx as ox
import os
from shapely.geometry import LineString
from shapely.geometry import Point
from shapely.geometry import Polygon
import shapely.ops as so
import pandas as pd
import numpy as np

import importlib

import helper_functions.utils
import helper_functions.plot_utils
import helper_functions.routing.driving
import helper_functions.routing.publicTransit

importlib.reload(helper_functions.utils)
importlib.reload(helper_functions.plot_utils)
importlib.reload(helper_functions.routing.driving)
importlib.reload(helper_functions.routing.publicTransit)

import helper_functions.utils as utils
import helper_functions.plot_utils as plot_utils
import helper_functions.routing.driving as driving
import helper_functions.routing.publicTransit as publicTransit

# %%
# configure the place, network type, trip times, and travel speed
place = {"city": "Singapore", "country": "Singapore"}
network_type = "drive"
trip_times = [15,30,45,60,90]  # in minutes
trip_times = [i*60 for i in trip_times] # in seconds
trip_times
# speed limit is 50 km/h unless otherwise stated
# school zones = 40 km/h
# silver zones for senior pedestrians = 30 - 40 km/h
# expressway = 70 - 90 km/h for cars; 60 km/h for buses
# tunnels = 50 - 80 km/h, depending on vehicle type
# Out:
# [900, 1800, 2700, 3600, 5400]

# %% [markdown]
# # Plot/save drive network

# %%
# # download/model a street network for some city then visualize it
# G_drive = ox.graph_from_place(place, network_type=network_type)

# # # save driving network
save_dir = os.path.join(os.getcwd(),"data")
# if not os.path.exists(save_dir):
#     os.mkdir(save_dir)
filename = "SG_drive_network.graphml"
# # save graph to disk as GraphML file
# ox.save_graphml(G_drive, filepath=os.path.join(save_dir,filename))

# load graph from disk
G_drive = ox.load_graphml(os.path.join(save_dir,filename))
fig, ax = ox.plot_graph(G_drive, node_size=0, edge_color="w", edge_linewidth=0.2)

# %% [markdown]
# # Inspect speed limits

# %%
# see mean speed/time values by road type
edges = ox.graph_to_gdfs(G_drive, nodes=False)
edges.head()
# Out:
#                                                                      osmid  \
# u        v          key
# 25451929 6749812859 0    [49961799, 718881456, 741164883, 754786742, 17...
# 25455287 1637003462 0                                            150829205
#          2521018789 0                     [633215386, 74607482, 635109319]
# 26777521 172424179  0                    [481674707, 654734557, 633179143]
#          1889379421 0         [643413273, 559564482, 640203517, 640203518]
#
#                                highway   lanes maxspeed  \
# u        v          key
# 25451929 6749812859 0         motorway       5       70
# 25455287 1637003462 0    motorway_link       1       50
#          2521018789 0         motorway  [2, 3]       90
# 26777521 172424179  0          primary       2       40
#          1889379421 0      residential       2       50
#
#                                                   name  oneway  ref reversed  \
# u        v          key
# 25451929 6749812859 0               East Coast Parkway    True  ECP    False
# 25455287 1637003462 0    Kallang Paya Lebar Expressway    True  NaN    False
#          2521018789 0               East Coast Parkway    True  ECP    False
# 26777521 172424179  0                      Grange Road    True  NaN    False
#          1889379421 0                    Cuscaden Road   False  NaN    False
#
#                              length bridge  \
# u        v          key
# 25451929 6749812859 0    765.027747    yes
# 25455287 1637003462 0    629.055082    NaN
#          2521018789 0    652.575579    NaN
# 26777521 172424179  0    113.995770    NaN
#          1889379421 0     86.667744    NaN
#
#                                                                   geometry  \
# u        v          key
# 25451929 6749812859 0    LINESTRING (103.87254 1.29523, 103.87103 1.295...
# 25455287 1637003462 0    LINESTRING (103.874 1.29544, 103.87413 1.2955,...
#          2521018789 0    LINESTRING (103.874 1.29544, 103.87438 1.29544...
# 26777521 172424179  0    LINESTRING (103.82357 1.30398, 103.82359 1.303...
#          1889379421 0    LINESTRING (103.82357 1.30398, 103.82372 1.304...
#
#                         tunnel junction access width
# u        v          key
# 25451929 6749812859 0      NaN      NaN    NaN   NaN
# 25455287 1637003462 0      NaN      NaN    NaN   NaN
#          2521018789 0      NaN      NaN    NaN   NaN
# 26777521 172424179  0      NaN      NaN    NaN   NaN
#          1889379421 0      NaN      NaN    NaN   NaN

# %%
edges[edges['maxspeed'].isna()]
# Out:
#                                                                          osmid  \
# u           v           key
# 237296759   249799919   0    [480746656, 174552487, 167648620, 25864563, 48...
# 237420004   11385801833 0                                           1125141703
# 239701951   12213144214 0                                           1319768709
#             12213144223 0                                           1319768709
# 240002104   2598074293  0                                            253945337
# ...                                                                        ...
# 9658768591  9658768592  0                                           1051060329
# 9658768592  9658768594  0                                           1051060329
# 10806629050 2325064861  0                                            223626312
# 11829817082 11829817077 0                                           1273997441
# 12005108712 12005108716 0                                           1295550998
#
#                                   highway   lanes maxspeed  \
# u           v           key
# 237296759   249799919   0        motorway  [4, 3]      NaN
# 237420004   11385801833 0     residential     NaN      NaN
# 239701951   12213144214 0        tertiary       2      NaN
#             12213144223 0        tertiary       2      NaN
# 240002104   2598074293  0        tertiary       2      NaN
# ...                                   ...     ...      ...
# 9658768591  9658768592  0        tertiary     NaN      NaN
# 9658768592  9658768594  0        tertiary     NaN      NaN
# 10806629050 2325064861  0     residential     NaN      NaN
# 11829817082 11829817077 0    primary_link     NaN      NaN
# 12005108712 12005108716 0     residential     NaN      NaN
#
#                                                name  oneway  ref reversed  \
# u           v           key
# 237296759   249799919   0        Central Expressway    True  CTE    False
# 237420004   11385801833 0       Holland Village Way    True  NaN    False
# 239701951   12213144214 0    South Buona Vista Road   False  NaN    False
#             12213144223 0    South Buona Vista Road   False  NaN     True
# 240002104   2598074293  0           Commerce Street   False  NaN    False
# ...                                             ...     ...  ...      ...
# 9658768591  9658768592  0    Tanah Merah Coast Road    True  NaN    False
# 9658768592  9658768594  0    Tanah Merah Coast Road    True  NaN    False
# 10806629050 2325064861  0                       NaN   False  NaN     True
# 11829817082 11829817077 0                       NaN    True  NaN    False
# 12005108712 12005108716 0                       NaN    True  NaN    False
#
#                                  length bridge  \
# u           v           key
# 237296759   249799919   0    537.198578    NaN
# 237420004   11385801833 0      7.759250    NaN
# 239701951   12213144214 0     41.585428    NaN
#             12213144223 0    277.824087    NaN
# 240002104   2598074293  0     60.566671    NaN
# ...                                 ...    ...
# 9658768591  9658768592  0     70.488473    NaN
# 9658768592  9658768594  0    393.334773    NaN
# 10806629050 2325064861  0     46.676889    NaN
# 11829817082 11829817077 0     29.249508    NaN
# 12005108712 12005108716 0     24.343332    NaN
#
#                                                                       geometry  \
# u           v           key
# 237296759   249799919   0    LINESTRING (103.84205 1.28912, 103.84184 1.288...
# 237420004   11385801833 0    LINESTRING (103.79264 1.31122, 103.79271 1.31123)
# 239701951   12213144214 0    LINESTRING (103.78748 1.2822, 103.78735 1.2820...
#             12213144223 0    LINESTRING (103.78748 1.2822, 103.78769 1.2823...
# 240002104   2598074293  0    LINESTRING (103.85056 1.27995, 103.85067 1.279...
# ...                                                                        ...
# 9658768591  9658768592  0    LINESTRING (104.00425 1.31215, 104.00424 1.312...
# 9658768592  9658768594  0    LINESTRING (104.00448 1.3127, 104.00719 1.3145...
# 10806629050 2325064861  0    LINESTRING (103.90744 1.30722, 103.90709 1.30699)
# 11829817082 11829817077 0    LINESTRING (103.99749 1.31309, 103.99757 1.313...
# 12005108712 12005108716 0    LINESTRING (103.90675 1.30345, 103.90669 1.303...
#
#                             tunnel junction access width
# u           v           key
# 237296759   249799919   0      yes      NaN    NaN   NaN
# 237420004   11385801833 0      NaN      NaN    NaN   NaN
# 239701951   12213144214 0      NaN      NaN    NaN   NaN
#             12213144223 0      NaN      NaN    NaN   NaN
# 240002104   2598074293  0      NaN      NaN    NaN   NaN
# ...                            ...      ...    ...   ...
# 9658768591  9658768592  0      NaN      NaN    NaN   NaN
# 9658768592  9658768594  0      NaN      NaN    NaN   NaN
# 10806629050 2325064861  0      NaN      NaN    NaN   NaN
# 11829817082 11829817077 0      NaN      NaN    NaN   NaN
# 12005108712 12005108716 0      NaN      NaN    NaN   NaN
#
# [2225 rows x 15 columns]

# %% [markdown]
# ## Check if edges lie within school zones or silver zones

# %%
SchoolZones = gpd.read_file(r"C:\Users\hypak\OneDrive - Singapore Management University\Documents\Data\SG_LTA\SchoolZone_Nov2024\SCHOOLZONE.shp")
print(SchoolZones.crs)
SchoolZones = SchoolZones.to_crs(edges.crs)
print(SchoolZones.crs)
SchoolZones.head()
# Out:
# PROJCS["SVY21",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",1.36666666666667],PARAMETER["central_meridian",103.833333333333],PARAMETER["scale_factor",1],PARAMETER["false_easting",28001.642],PARAMETER["false_northing",38744.572],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# epsg:4326
#                         SITENAME   INC_CRC FMEL_UPD_D  \
# 0  Tampines North Primary School  F3A9A20A 2016-03-29
# 1   Chij (Katong) Primary School  54B7FF5E 2016-03-29
# 2                   Metta School  2B880636 2016-03-29
# 3    Opera Estate Primary School  A838D0F7 2016-03-29
# 4       Minds-Towner Gdns School  86AC26B3 2016-03-29
#
#                                             geometry
# 0  POLYGON ((103.94872 1.36007, 103.94894 1.36001...
# 1  POLYGON ((103.91083 1.30752, 103.91106 1.30692...
# 2  POLYGON ((103.95627 1.34661, 103.9578 1.34649,...
# 3  POLYGON ((103.92235 1.31926, 103.9225 1.31925,...
# 4  POLYGON ((103.91371 1.32708, 103.91372 1.32681...

# %%
SilverZones = gpd.read_file(r"C:\Users\hypak\OneDrive - Singapore Management University\Documents\Data\SG_LTA\SilverZone_Nov2024\SILVERZONE.shp")
print(SilverZones.crs)
SilverZones = SilverZones.to_crs(edges.crs)
print(SilverZones.crs)
SilverZones.head()
# Out:
# PROJCS["SVY21",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",1.36666666666667],PARAMETER["central_meridian",103.833333333333],PARAMETER["scale_factor",1],PARAMETER["false_easting",28001.642],PARAMETER["false_northing",38744.572],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# epsg:4326
#                      SITENAME           INC_CRC FMEL_UPD_D  \
# 0              TECK WHYE LANE  D9DA16AB69A7035F 2024-01-07
# 1              CHAI CHEE ROAD  3BD0A7504BF9921B 2024-01-07
# 2      TELOK BLANGAH CRESCENT  0B38BC5EFC04D840 2024-01-07
# 3           HOUGANG STREET 21  FBADDED03B06EF73 2024-01-07
# 4  POTONG PASIR AVE 1 & AVE 2  8923AB6D26C7F1BE 2024-01-07
#
#                                             geometry
# 0  POLYGON ((103.75238 1.37963, 103.75222 1.37961...
# 1  POLYGON ((103.92315 1.32282, 103.92317 1.32283...
# 2  POLYGON ((103.81797 1.2775, 103.81782 1.27774,...
# 3  POLYGON ((103.8831 1.35814, 103.88309 1.3581, ...
# 4  POLYGON ((103.86649 1.33147, 103.86652 1.33146...

# %%
# print(len(SchoolZones.index))
# print(len(SilverZones.index))
def get_roads_within_zones(specialZones,roads):
    """ 
    get roads that are within school zones/silver zones
    Args:
        specialZones (gdf): gdf of zones in Polygons
        roads (gdf): roads that are represented in the form of ox.edges
    Returns:
        edges id: edges' index (u to v)
    """
    edges = []
    for z in specialZones.geometry: # Polygon
        rd = roads[roads.geometry.within(z)] # subset roads that lie within Polygons
        edges.append(rd)

    return pd.concat(edges)

sch_edges = get_roads_within_zones(SchoolZones,edges)
sch_edges
# Out:
#                                                                        osmid  \
# u          v          key
# 243679058  992571784  0                                            173767905
# 992571784  5015699374 0                                            512991758
# 5015699374 5015699375 0                                            512991759
# 5015699375 243679058  0                                            512991757
# 258306066  1849458079 0                     [737660688, 737660689, 23837148]
# ...                                                                      ...
# 5950255468 245174809  0                                            630075834
# 9080932827 9080932825 0                                            464809797
#            4598816973 0                                            479616490
# 4598826810 6244033776 0    [627932386, 536039235, 825713064, 825713065, 8...
# 6244033776 5015083863 0                    [825713066, 628007114, 628009023]
#
#                                   highway   lanes maxspeed  \
# u          v          key
# 243679058  992571784  0       residential     NaN       50
# 992571784  5015699374 0         secondary       2       40
# 5015699374 5015699375 0       residential     NaN       50
# 5015699375 243679058  0         secondary       2       60
# 258306066  1849458079 0       residential       4       40
# ...                                   ...     ...      ...
# 5950255468 245174809  0       residential       2       50
# 9080932827 9080932825 0    secondary_link       1       40
#            4598816973 0         secondary       2       40
# 4598826810 6244033776 0       residential       1       40
# 6244033776 5015083863 0       residential  [2, 1]       40
#
#                                          name  oneway  ref reversed  \
# u          v          key
# 243679058  992571784  0    Tampines Street 41    True  NaN    False
# 992571784  5015699374 0     Tampines Avenue 9    True  NaN    False
# 5015699374 5015699375 0    Tampines Street 41    True  NaN    False
# 5015699375 243679058  0     Tampines Avenue 9    True  NaN    False
# 258306066  1849458079 0       Jalan Kembangan   False  NaN     True
# ...                                       ...     ...  ...      ...
# 5950255468 245174809  0           Fulton Road   False  NaN     True
# 9080932827 9080932825 0                   NaN    True  NaN    False
#            4598816973 0       Sin Ming Avenue    True  NaN    False
# 4598826810 6244033776 0       Anchorvale Link    True  NaN    False
# 6244033776 5015083863 0       Anchorvale Link    True  NaN    False
#
#                                length bridge  \
# u          v          key
# 243679058  992571784  0     11.288950    NaN
# 992571784  5015699374 0      5.492852    NaN
# 5015699374 5015699375 0     11.366769    NaN
# 5015699375 243679058  0      5.491670    NaN
# 258306066  1849458079 0    124.123795    NaN
# ...                               ...    ...
# 5950255468 245174809  0     11.515708    NaN
# 9080932827 9080932825 0     23.817602    NaN
#            4598816973 0     14.976867    NaN
# 4598826810 6244033776 0    116.423063    NaN
# 6244033776 5015083863 0    115.879692    NaN
#
#                                                                     geometry  \
# u          v          key
# 243679058  992571784  0    LINESTRING (103.94932 1.35978, 103.94932 1.35988)
# 992571784  5015699374 0    LINESTRING (103.94932 1.35988, 103.94937 1.35988)
# 5015699374 5015699375 0    LINESTRING (103.94937 1.35988, 103.94937 1.35978)
# 5015699375 243679058  0    LINESTRING (103.94937 1.35978, 103.94932 1.35978)
# 258306066  1849458079 0    LINESTRING (103.91349 1.32534, 103.9135 1.3254...
# ...                                                                      ...
# 5950255468 245174809  0    LINESTRING (103.83201 1.36184, 103.83211 1.36182)
# 9080932827 9080932825 0    LINESTRING (103.83212 1.36043, 103.83217 1.360...
#            4598816973 0    LINESTRING (103.83212 1.36043, 103.83212 1.360...
# 4598826810 6244033776 0    LINESTRING (103.89055 1.39453, 103.89059 1.394...
# 6244033776 5015083863 0    LINESTRING (103.89073 1.39555, 103.89075 1.395...
#
#                           tunnel junction access width
# u          v          key
# 243679058  992571784  0      NaN      NaN    NaN   NaN
# 992571784  5015699374 0      NaN      NaN    NaN   NaN
# 5015699374 5015699375 0      NaN      NaN    NaN   NaN
# 5015699375 243679058  0      NaN      NaN    NaN   NaN
# 258306066  1849458079 0      NaN      NaN    NaN   NaN
# ...                          ...      ...    ...   ...
# 5950255468 245174809  0      NaN      NaN    NaN   NaN
# 9080932827 9080932825 0      NaN      NaN    NaN   NaN
#            4598816973 0      NaN      NaN    NaN   NaN
# 4598826810 6244033776 0      NaN      NaN    NaN   NaN
# 6244033776 5015083863 0      NaN      NaN    NaN   NaN
#
# [326 rows x 15 columns]

# %%
edges.loc[sch_edges.index,'maxspeed']
# Out:
# u           v           key
# 243679058   992571784   0      50
# 992571784   5015699374  0      40
# 5015699374  5015699375  0      50
# 5015699375  243679058   0      60
# 258306066   1849458079  0      40
#                                ..
# 5950255468  245174809   0      50
# 9080932827  9080932825  0      40
#             4598816973  0      40
# 4598826810  6244033776  0      40
# 6244033776  5015083863  0      40
# Name: maxspeed, Length: 326, dtype: object

# %%
edges.loc[sch_edges.index,'maxspeed'] = 40 # sch zone speed limit is 40
edges.loc[sch_edges.index,'maxspeed']
# Out:
# u           v           key
# 243679058   992571784   0      40
# 992571784   5015699374  0      40
# 5015699374  5015699375  0      40
# 5015699375  243679058   0      40
# 258306066   1849458079  0      40
#                                ..
# 5950255468  245174809   0      40
# 9080932827  9080932825  0      40
#             4598816973  0      40
# 4598826810  6244033776  0      40
# 6244033776  5015083863  0      40
# Name: maxspeed, Length: 326, dtype: object

# %%
silver_edges = get_roads_within_zones(SilverZones,edges)
silver_edges
# Out:
#                                                                        osmid  \
# u          v          key
# 243713498  243713550  0    [644243460, 631905521, 669863123, 631889045, 6...
# 243713550  243713498  0    [644243460, 631905521, 669863123, 631889045, 6...
#            4945784620 0    [632829888, 676155366, 22721849, 640182778, 64...
# 4945784620 243713550  0    [632829888, 676155366, 22721849, 640182778, 64...
# 2238840352 5599434282 0                                            644417768
# ...                                                                      ...
# 4753394967 4753394968 0                                            537120322
# 4753394968 4753394965 0                                            482534353
# 5178982356 5178982357 0                                            482522726
# 5178982357 4740612730 0                                            537120324
#            905160623  0    [639906946, 537120323, 644974469, 644987913, 4...
#
#                                highway   lanes maxspeed  \
# u          v          key
# 243713498  243713550  0    residential       2       50
# 243713550  243713498  0    residential       2       50
#            4945784620 0    residential       2       50
# 4945784620 243713550  0    residential       2       50
# 2238840352 5599434282 0    residential     NaN      NaN
# ...                                ...     ...      ...
# 4753394967 4753394968 0       tertiary       2       40
# 4753394968 4753394965 0    residential       1       40
# 5178982356 5178982357 0    residential       1       40
# 5178982357 4740612730 0       tertiary       3       50
#            905160623  0    residential  [2, 1]       40
#
#                                             name  oneway  ref reversed  \
# u          v          key
# 243713498  243713550  0           Teck Whye Lane   False  NaN    False
# 243713550  243713498  0           Teck Whye Lane   False  NaN     True
#            4945784620 0           Teck Whye Lane   False  NaN    False
# 4945784620 243713550  0           Teck Whye Lane   False  NaN     True
# 2238840352 5599434282 0         Chai Chee Avenue   False  NaN    False
# ...                                          ...     ...  ...      ...
# 4753394967 4753394968 0    Jurong West Street 51    True  NaN    False
# 4753394968 4753394965 0    Jurong West Street 52    True  NaN    False
# 5178982356 5178982357 0    Jurong West Street 52    True  NaN    False
# 5178982357 4740612730 0     Jurong West Avenue 1    True  NaN    False
#            905160623  0    Jurong West Street 52    True  NaN    False
#
#                                length bridge  \
# u          v          key
# 243713498  243713550  0    365.345939    NaN
# 243713550  243713498  0    365.345939    NaN
#            4945784620 0    131.032923    NaN
# 4945784620 243713550  0    131.032923    NaN
# 2238840352 5599434282 0      3.503509    NaN
# ...                               ...    ...
# 4753394967 4753394968 0      8.687099    NaN
# 4753394968 4753394965 0      7.274105    NaN
# 5178982356 5178982357 0      8.079521    NaN
# 5178982357 4740612730 0      9.467593    NaN
#            905160623  0    825.919130    NaN
#
#                                                                     geometry  \
# u          v          key
# 243713498  243713550  0    LINESTRING (103.7525 1.37967, 103.75251 1.3796...
# 243713550  243713498  0    LINESTRING (103.75464 1.37812, 103.75462 1.378...
#            4945784620 0    LINESTRING (103.75464 1.37812, 103.75464 1.378...
# 4945784620 243713550  0    LINESTRING (103.75475 1.37695, 103.75474 1.377...
# 2238840352 5599434282 0      LINESTRING (103.9232 1.3253, 103.92324 1.32529)
# ...                                                                      ...
# 4753394967 4753394968 0    LINESTRING (103.72112 1.34696, 103.72115 1.34689)
# 4753394968 4753394965 0    LINESTRING (103.72115 1.34689, 103.72111 1.346...
# 5178982356 5178982357 0    LINESTRING (103.71721 1.35052, 103.71724 1.35046)
# 5178982357 4740612730 0    LINESTRING (103.71724 1.35046, 103.71716 1.35042)
#            905160623  0    LINESTRING (103.71724 1.35046, 103.71725 1.350...
#
#                           tunnel junction access width
# u          v          key
# 243713498  243713550  0      NaN      NaN    NaN   NaN
# 243713550  243713498  0      NaN      NaN    NaN   NaN
#            4945784620 0      NaN      NaN    NaN   NaN
# 4945784620 243713550  0      NaN      NaN    NaN   NaN
# 2238840352 5599434282 0      NaN      NaN    NaN   NaN
# ...                          ...      ...    ...   ...
# 4753394967 4753394968 0      NaN      NaN    NaN   NaN
# 4753394968 4753394965 0      NaN      NaN    NaN   NaN
# 5178982356 5178982357 0      NaN      NaN    NaN   NaN
# 5178982357 4740612730 0      NaN      NaN    NaN   NaN
#            905160623  0      NaN      NaN    NaN   NaN
#
# [219 rows x 15 columns]

# %%
edges.loc[silver_edges.index,'maxspeed'] = 40 # silver zones for senior pedestrians = 30 - 40 km/h, but just take the upper limit
edges.loc[silver_edges.index,'maxspeed']
# Out:
# u           v           key
# 243713498   243713550   0      40
# 243713550   243713498   0      40
#             4945784620  0      40
# 4945784620  243713550   0      40
# 2238840352  5599434282  0      40
#                                ..
# 4753394967  4753394968  0      40
# 4753394968  4753394965  0      40
# 5178982356  5178982357  0      40
# 5178982357  4740612730  0      40
#             905160623   0      40
# Name: maxspeed, Length: 219, dtype: object

# %% [markdown]
# ### Identify non-numeric values in maxspeed

# %%
null_index = edges[~pd.to_numeric(edges.maxspeed, errors='coerce').notnull()].index
edges.loc[null_index,:]
# Out:
#                                                                          osmid  \
# u           v           key
# 139642419   4728054624  0    [479174082, 479174083, 74628616, 479757261, 15...
# 141883271   566224675   0    [480749315, 480749316, 480749319, 480749320, 4...
# 172517972   1931968476  0    [649336169, 302367561, 639902539, 649957995, 7...
# 232105452   2015361448  0                    [173779737, 826342061, 639881927]
# 237054768   12071463880 0    [35037538, 528539591, 459186769, 173779730, 35...
# ...                                                                        ...
# 9658768591  9658768592  0                                           1051060329
# 9658768592  9658768594  0                                           1051060329
# 10806629050 2325064861  0                                            223626312
# 11829817082 11829817077 0                                           1273997441
# 12005108712 12005108716 0                                           1295550998
#
#                                             highway   lanes  maxspeed  \
# u           v           key
# 139642419   4728054624  0                  motorway       3  [80, 90]
# 141883271   566224675   0                  motorway       3  [80, 90]
# 172517972   1931968476  0    [trunk_link, tertiary]       2  [50, 40]
# 232105452   2015361448  0                 secondary       3  [50, 40]
# 237054768   12071463880 0                     trunk  [5, 4]  [70, 60]
# ...                                             ...     ...       ...
# 9658768591  9658768592  0                  tertiary     NaN       NaN
# 9658768592  9658768594  0                  tertiary     NaN       NaN
# 10806629050 2325064861  0               residential     NaN       NaN
# 11829817082 11829817077 0              primary_link     NaN       NaN
# 12005108712 12005108716 0               residential     NaN       NaN
#
#                                                           name  oneway  ref  \
# u           v           key
# 139642419   4728054624  0                Pan-Island Expressway    True  PIE
# 141883271   566224675   0                Ayer Rajah Expressway    True  AYE
# 172517972   1931968476  0                         Stadium Road    True  NaN
# 232105452   2015361448  0                         Jalan Sultan    True  NaN
# 237054768   12071463880 0    [Fullerton Road, Esplanade Drive]    True  NaN
# ...                                                        ...     ...  ...
# 9658768591  9658768592  0               Tanah Merah Coast Road    True  NaN
# 9658768592  9658768594  0               Tanah Merah Coast Road    True  NaN
# 10806629050 2325064861  0                                  NaN   False  NaN
# 11829817082 11829817077 0                                  NaN    True  NaN
# 12005108712 12005108716 0                                  NaN    True  NaN
#
#                             reversed       length bridge  \
# u           v           key
# 139642419   4728054624  0      False   523.640401    yes
# 141883271   566224675   0      False  2546.445190    NaN
# 172517972   1931968476  0      False   760.029468    yes
# 232105452   2015361448  0      False   207.761368    NaN
# 237054768   12071463880 0      False   541.885182    yes
# ...                              ...          ...    ...
# 9658768591  9658768592  0      False    70.488473    NaN
# 9658768592  9658768594  0      False   393.334773    NaN
# 10806629050 2325064861  0       True    46.676889    NaN
# 11829817082 11829817077 0      False    29.249508    NaN
# 12005108712 12005108716 0      False    24.343332    NaN
#
#                                                                       geometry  \
# u           v           key
# 139642419   4728054624  0    LINESTRING (103.8799 1.32008, 103.87966 1.32, ...
# 141883271   566224675   0    LINESTRING (103.82015 1.27899, 103.81924 1.279...
# 172517972   1931968476  0    LINESTRING (103.87021 1.3055, 103.8706 1.30584...
# 232105452   2015361448  0    LINESTRING (103.86081 1.3042, 103.86086 1.3041...
# 237054768   12071463880 0    LINESTRING (103.85371 1.28639, 103.85376 1.286...
# ...                                                                        ...
# 9658768591  9658768592  0    LINESTRING (104.00425 1.31215, 104.00424 1.312...
# 9658768592  9658768594  0    LINESTRING (104.00448 1.3127, 104.00719 1.3145...
# 10806629050 2325064861  0    LINESTRING (103.90744 1.30722, 103.90709 1.30699)
# 11829817082 11829817077 0    LINESTRING (103.99749 1.31309, 103.99757 1.313...
# 12005108712 12005108716 0    LINESTRING (103.90675 1.30345, 103.90669 1.303...
#
#                             tunnel junction access width
# u           v           key
# 139642419   4728054624  0      NaN      NaN    NaN   NaN
# 141883271   566224675   0      NaN      NaN    NaN   NaN
# 172517972   1931968476  0      NaN      NaN    NaN   NaN
# 232105452   2015361448  0      NaN      NaN    NaN   NaN
# 237054768   12071463880 0      NaN      NaN    NaN   NaN
# ...                            ...      ...    ...   ...
# 9658768591  9658768592  0      NaN      NaN    NaN   NaN
# 9658768592  9658768594  0      NaN      NaN    NaN   NaN
# 10806629050 2325064861  0      NaN      NaN    NaN   NaN
# 11829817082 11829817077 0      NaN      NaN    NaN   NaN
# 12005108712 12005108716 0      NaN      NaN    NaN   NaN
#
# [2685 rows x 15 columns]

# %% [markdown]
# ### Replace NA values

# %%
na_speeds = edges[~pd.to_numeric(edges.maxspeed, errors='coerce').notnull()]['maxspeed']
def get_max_speed(speed_list, replace_na = 50):
    """ Converts str to float then select max speed
    Args:
        speed_list (list of str or np.NaN): sometimes in OSM, the max speed is described as a list of str
        replace_na (float): replace np.NaN values with a float value. Default speed limit is 50 km/h
    Returns:
        float: max speed
    """
    if isinstance(speed_list, list):
        return max([float(s) for s in speed_list])
    elif np.isnan(speed_list):
        return replace_na
    else:
        return np.nan

na_speeds = na_speeds.apply(get_max_speed)
# replace NA rows with updated values
edges.loc[null_index,'maxspeed'] = na_speeds
edges.loc[null_index,'maxspeed']
# Out:
# u            v            key
# 139642419    4728054624   0      90.0
# 141883271    566224675    0      90.0
# 172517972    1931968476   0      50.0
# 232105452    2015361448   0      50.0
# 237054768    12071463880  0      70.0
#                                  ...
# 9658768591   9658768592   0      50.0
# 9658768592   9658768594   0      50.0
# 10806629050  2325064861   0      50.0
# 11829817082  11829817077  0      50.0
# 12005108712  12005108716  0      50.0
# Name: maxspeed, Length: 2685, dtype: object

# %% [markdown]
# # Visualise edge maxspeed

# %%
# check if there are NAs or nulls in maxspeed
print('Number of nulls/NAs: ',len(edges[~pd.to_numeric(edges.maxspeed, errors='coerce').notnull()]['maxspeed'].index))
print('Are there no NAs? ',edges['maxspeed'].notna().all())
print('Are there no nulls? ',edges['maxspeed'].notnull().all())
# convert dtype object to numeric
edges['maxspeed'] = pd.to_numeric(edges['maxspeed'])
print(edges.dtypes)
print('Are there no NAs? ',edges['maxspeed'].notna().all())
print('Are there no nulls? ',edges['maxspeed'].notnull().all())
# Out:
# Number of nulls/NAs:  0
# Are there no NAs?  True
# Are there no nulls?  True
# osmid         object
# highway       object
# lanes         object
# maxspeed     float64
# name          object
# oneway          bool
# ref           object
# reversed      object
# length       float64
# bridge        object
# geometry    geometry
# tunnel        object
# junction      object
# access        object
# width         object
# dtype: object
# Are there no NAs?  True
# Are there no nulls?  True

# %% [markdown]
# ### Replace maxspeed attributes with the updated one (G_car)

# %%
print('Does the number of edges match? ',len(G_drive.edges()) == len(edges.index))
for (_, _, _, data),maxspeed in zip(G_drive.edges(data=True, keys=True),edges['maxspeed']):
    data['maxspeed'] = maxspeed
# Out:
# Does the number of edges match?  True

# %% [markdown]
# # Visualise roads' maxspeed limit (G_car)

# %%
# get node colors by linearly mapping an attribute's values to a colormap
ec = ox.plot.get_edge_colors_by_attr(G_drive, attr="maxspeed", cmap='plasma',num_bins=5)
# fig, ax = ox.plot_graph(G_drive, node_size=0, edge_color=ec, bgcolor="white")
# plot the graph with colored edges
fig, ax = ox.plot_graph(G_drive, node_size=0, edge_color=ec)

# %%
ec_colors = pd.concat([edges['maxspeed'],ec],axis=1).groupby(0)['maxspeed'].apply(lambda x: f'{x.min()}-{x.max()} km/h').reset_index()
ec_colors
# Out:
#          0        maxspeed
# 0  #0d0887  10.0-25.0 km/h
# 1  #7e03a8  30.0-40.0 km/h
# 2  #cc4778  50.0-50.0 km/h
# 3  #f0f921  80.0-90.0 km/h
# 4  #f89540  60.0-70.0 km/h

# %%
# hex colors are stored in the column 0, maxspeed labels are stored in the column maxspeed
plot_utils.plot_colortable(ec_colors[0], ec_colors['maxspeed'], ncols=3, sort_colors=False)

# %% [markdown]
# # Add edge travel times (G_car)
# - `osmnx.routing.add_edge_speeds(G)`
#     - By default, this imputes free-flow travel speeds for all edges via the mean *maxspeed* value of the edges of each highway type.
#     - For highway types in the graph that have no maxspeed value on any edge, it assigns the mean of all *maxspeed* values in graph.
#     - Returns: Graph with *speed_kph* attributes on all edges
# - `osmnx.routing.add_edge_travel_times(G)`
#     - Add edge travel time (seconds) to graph as new travel_time edge attributes.
#     - Calculates free-flow travel time along each edge, based on length and speed_kph attributes. Note: run `add_edge_speeds` first to generate the speed_kph attribute. All edges must have length and speed_kph attributes and all their values must be non-null.
#     - Returns: Graph with *travel_time* attributes on all edges

# %%
# impute speed on all edges missing data
G_car = ox.add_edge_speeds(G_drive)

# calculate travel time (seconds) for all edges
G_car = ox.add_edge_travel_times(G_car)

# %%
# get node colors by linearly mapping an attribute's values to a colormap
ec = ox.plot.get_edge_colors_by_attr(G_car, attr="speed_kph", cmap='plasma',num_bins=5)
# fig, ax = ox.plot_graph(G_car, node_size=0, edge_color=ec, bgcolor="white")
# plot the graph with colored edges
fig, ax = ox.plot_graph(G_car, node_size=0, edge_color=ec)

# %%
edges = ox.graph_to_gdfs(G_car, nodes=False)
ec_colors = pd.concat([edges['speed_kph'],ec],axis=1).groupby(0)['speed_kph'].apply(lambda x: f'{x.min()}-{x.max()} km/h').reset_index()
# hex colors are stored in the column 0, speed_kph labels are stored in the column speed_kph
plot_utils.plot_colortable(ec_colors[0], ec_colors['speed_kph'], ncols=3, sort_colors=False)

# %% [markdown]
# ### View speed_kph and travel_time (seconds) by road types

# %%
edges["highway"] = edges["highway"].astype(str)
edges.groupby("highway")[["length", "speed_kph", "travel_time"]].mean().round(1)
# Out:
#                                               length  speed_kph  travel_time
# highway
# ['motorway_link', 'motorway']                  451.0       50.0         32.5
# ['motorway_link', 'primary']                   379.4       65.0         20.7
# ['motorway_link', 'secondary']                 461.1       54.0         32.7
# ['motorway_link', 'tertiary']                  555.8       50.0         40.0
# ['primary', 'primary_link']                   1368.1       65.0         71.2
# ['primary', 'secondary']                       271.6       60.0         16.3
# ['primary_link', 'secondary']                  495.9       50.0         35.7
# ['primary_link', 'tertiary']                  1300.6       50.0         93.6
# ['residential', 'living_street']               231.2       50.0         16.6
# ['residential', 'secondary']                    20.5       50.0          1.5
# ['residential', 'tertiary']                    240.6       45.0         21.4
# ['residential', 'tertiary_link', 'tertiary']   495.9       50.0         35.7
# ['residential', 'tertiary_link']               168.8       50.0         12.2
# ['residential', 'unclassified']                670.5       50.0         48.3
# ['secondary_link', 'secondary']                428.5       50.0         30.9
# ['secondary_link', 'tertiary']                 208.6       50.0         15.0
# ['tertiary', 'primary_link']                   327.2       50.0         23.6
# ['tertiary', 'secondary']                      312.3       53.3         21.6
# ['tertiary_link', 'residential', 'tertiary']   472.3       50.0         34.0
# ['tertiary_link', 'residential']               304.2       40.0         27.4
# ['tertiary_link', 'tertiary']                  505.5       47.5         37.2
# ['tertiary_link', 'unclassified']               67.2       50.0          4.8
# ['trunk_link', 'primary']                       17.9       60.0          1.1
# ['trunk_link', 'tertiary']                     429.8       50.0         30.9
# ['trunk_link', 'trunk']                        127.5       70.0          6.6
# ['unclassified', 'primary']                     13.8       70.0          0.7
# ['unclassified', 'residential']                461.1       50.0         33.2
# living_street                                   65.0       50.0          4.7
# motorway                                       707.0       84.2         29.9
# motorway_link                                  206.0       50.6         14.5
# primary                                        137.3       60.6          8.1
# primary_link                                    56.9       50.2          4.1
# residential                                    111.7       47.1          8.6
# road                                            18.9       50.0          1.4
# secondary                                      124.4       53.7          8.4
# secondary_link                                  45.6       49.8          3.3
# tertiary                                       115.5       50.5          8.3
# tertiary_link                                   42.3       49.4          3.1
# trunk                                          155.8       59.0          8.9
# trunk_link                                     112.0       51.2          7.9
# unclassified                                   190.4       49.9         13.9

# %% [markdown]
# ### Export car network
# with the updated max speed limit

# %%
# # # # save walking network
save_dir = os.path.join(os.getcwd(),"data")
# # if not os.path.exists(save_dir):
# #     os.mkdir(save_dir)
filename = "SG_car_network.graphml"
# # # save graph to disk as GraphML file
# ox.save_graphml(G_car, filepath=os.path.join(save_dir,filename))

G_car = ox.load_graphml(os.path.join(save_dir,filename))

# %%
edges = ox.graph_to_gdfs(G_car, nodes=False)
edges.head()
# Out:
#                                                                      osmid  \
# u        v          key
# 25451929 6749812859 0    [49961799, 718881456, 741164883, 754786742, 17...
# 25455287 1637003462 0                                            150829205
#          2521018789 0                     [633215386, 74607482, 635109319]
# 26777521 172424179  0                    [481674707, 654734557, 633179143]
#          1889379421 0         [643413273, 559564482, 640203517, 640203518]
#
#                                highway   lanes maxspeed  \
# u        v          key
# 25451929 6749812859 0         motorway       5     70.0
# 25455287 1637003462 0    motorway_link       1     50.0
#          2521018789 0         motorway  [2, 3]     90.0
# 26777521 172424179  0          primary       2     40.0
#          1889379421 0      residential       2     50.0
#
#                                                   name  oneway  ref reversed  \
# u        v          key
# 25451929 6749812859 0               East Coast Parkway    True  ECP    False
# 25455287 1637003462 0    Kallang Paya Lebar Expressway    True  NaN    False
#          2521018789 0               East Coast Parkway    True  ECP    False
# 26777521 172424179  0                      Grange Road    True  NaN    False
#          1889379421 0                    Cuscaden Road   False  NaN    False
#
#                              length bridge  \
# u        v          key
# 25451929 6749812859 0    765.027747    yes
# 25455287 1637003462 0    629.055082    NaN
#          2521018789 0    652.575579    NaN
# 26777521 172424179  0    113.995770    NaN
#          1889379421 0     86.667744    NaN
#
#                                                                   geometry  \
# u        v          key
# 25451929 6749812859 0    LINESTRING (103.87254 1.29523, 103.87103 1.295...
# 25455287 1637003462 0    LINESTRING (103.874 1.29544, 103.87413 1.2955,...
#          2521018789 0    LINESTRING (103.874 1.29544, 103.87438 1.29544...
# 26777521 172424179  0    LINESTRING (103.82357 1.30398, 103.82359 1.303...
#          1889379421 0    LINESTRING (103.82357 1.30398, 103.82372 1.304...
#
#                          speed_kph  travel_time tunnel junction access width
# u        v          key
# 25451929 6749812859 0         70.0    39.344284    NaN      NaN    NaN   NaN
# 25455287 1637003462 0         50.0    45.291966    NaN      NaN    NaN   NaN
#          2521018789 0         90.0    26.103023    NaN      NaN    NaN   NaN
# 26777521 172424179  0         40.0    10.259619    NaN      NaN    NaN   NaN
#          1889379421 0         50.0     6.240078    NaN      NaN    NaN   NaN

# %% [markdown]
# # Import workplace cluster nodes

# %%
workplace_cluster = pd.read_csv(r"data\workplace_cluster.csv")
workplace_cluster
# Out:
#     latitude   longitude
# 0   1.320935  103.894151
# 1   1.327584  103.703464
# 2   1.448092  103.810287
# 3   1.284441  103.842959
# 4   1.295068  103.629310
# 5   1.356448  103.957308
# 6   1.299561  103.798223
# 7   1.309864  103.857340
# 8   1.374454  103.857601
# 9   1.320213  103.656895
# 10  1.415385  103.751913
# 11  1.326087  103.753416

# %%
workplace_cluster = pd.read_csv(r"data\workplace_cluster.csv")
workplace_cluster
workplace_nodes = ox.distance.nearest_nodes(G_car, X=workplace_cluster.longitude.to_list(), Y=workplace_cluster.latitude.to_list())
workplace_nodes
workplace_cluster['node_ID'] = workplace_nodes
workplace_cluster.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 workplace_cluster = pd.read_csv(r"data\workplace_cluster.csv")
#       2 workplace_cluster
# ----> 3 workplace_nodes = ox.distance.nearest_nodes(G_car, X=workplace_cluster.longitude.to_list(), Y=workplace_cluster.latitude.to_list())
#       4 workplace_nodes
#       5 workplace_cluster['node_ID'] = workplace_nodes
#
# NameError: name 'G_car' is not defined

# %%
iso_colors = ox.plot.get_colors(n=len(trip_times), cmap="plasma", start=0)
# hex colors are stored in the column 0, maxspeed labels are stored in the column maxspeed
plot_utils.plot_colortable(colors=list(reversed(iso_colors)), names=[f'{i//60} mins' for i in trip_times], ncols=2, sort_colors=False)

# %% [markdown]
# # Shortest path - driving
#
# Derive the shortest path between all combinations from workplace clusters to residential clusters
#
# `osmnx.routing.shortest_path(G, orig, dest, *, weight='length', cpus=1)`
# Solve shortest path from origin node(s) to destination node(s). This returns a list of lists of the nodes constituting the shortest path between each origin-destination pair.
#
# Since we are only interested in the shortest travel time (seconds) instead of the shortest route, we can use `networkx.shortest_path_length(G, source=None, target=None, weight=None, method='dijkstra')` to get the shortest time from orig to dest

# %%
drive_route_times = driving.get_shortest_path_driving(G_car,orig = workplace_nodes[0],dest=None)
drive_route_times
# Out:
# {np.int64(258305981): 0,
#  5118259982: 0.911401011182386,
#  5683697730: 1.653943092178995,
#  5683697728: 2.599012479785505,
#  5118259978: 4.031682937774908,
#  4604229240: 7.981543037333616,
#  4604229260: 12.384105136009257,
#  4604229261: 13.674530867975577,
#  4604229233: 14.348895243466991,
#  239826365: 14.455485878865225,
#  1726563965: 15.782887749685376,
#  4604229254: 17.75271935617484,
#  4604229247: 18.374586993181833,
#  4604229241: 20.341490666543866,
#  258305979: 24.27688668299045,
#  5683697731: 26.753203800246055,
#  239832558: 28.499025292821294,
#  1294427461: 29.139840028105432,
#  626311920: 31.746118951920632,
#  239832573: 33.20738551268695,
#  2426217331: 33.58459544222393,
#  246960838: 35.149922340627214,
#  4604229255: 36.013599931235206,
#  246961166: 36.17396207495932,
#  239833256: 36.45128196291303,
#  243670932: 36.86829787481398,
#  246960848: 38.31325070095102,
#  3118091525: 40.39590869186877,
#  254668821: 40.99690022069184,
#  4594224863: 41.162284503659436,
#  246960843: 41.65103020380386,
#  3109302810: 43.59801524725331,
#  246961164: 43.754254534259694,
#  206401588: 177.58284744309083,
#  4675560724: 177.6099890301668,
#  172549807: 177.81361234979323,
#  2061123569: 177.94945306699637,
#  778134809: 177.9810716753888,
#  1150246847: 177.9985935155824,
#  5596811228: 178.15252806448765,
#  2061123566: 178.19482019130768,
#  246957189: 178.30554380510273,
#  245929270: 178.37217293779273,
#  243674568: 178.40943017415037,
#  4712271379: 178.55009218932315,
#  377701419: 178.6059693556263,
#  1387646758: 178.61989711814996,
#  6065315582: 178.62771557007778,
#  258024149: 178.7022405843394,
#  245360615: 178.72635966848134,
#  4604305423: 178.7815932779855,
#  258304617: 178.84406912693223,
#  377682571: 178.85551301155436,
#  258304904: 178.8611285937495,
#  258023863: 178.87697405995638,
#  2927574668: 178.91093992571012,
#  259577627: 178.97282701284865,
#  7106228855: 179.0125108433473,
#  175258913: 179.10744207570735,
#  243674491: 179.21358365163408,
#  172549834: 179.21628839350467,
#  7106228853: 179.2415909544887,
#  258024193: 179.32234654649562,
#  258304599: 179.3225808293413,
#  259577634: 179.3672527211828,
#  258304801: 179.67240956832234,
#  139696656: 179.68501497944206,
#  230928179: 179.78679818231555,
#  ...}

# %%
planningArea_shp = gpd.read_file(r"C:\Users\hypak\OneDrive - Singapore Management University\Documents\Data\SG_Masterplan\MasterPlan2019_PlanningArea_Fixed.shp")
planningArea_shp.plot(fc='white',ec='k')
# Out:
# <Axes: >

# %%
iso_dir = os.path.join(r"data","isochrones")
if not os.path.exists(iso_dir):
    os.mkdir(iso_dir)
n_clusters = len(workplace_cluster.index)
ncols = 3
nrows = n_clusters//ncols
# define cbar 
cbar = plot_utils.get_colorbar(vmin=0,vmax=3600,cmap="plasma",plot=False)
fig, axes = plt.subplots(nrows, ncols, figsize = (ncols*4,nrows*3))
for i, ax in enumerate(axes.flatten()):
    # plot planning area boundary
    planningArea_shp.plot(fc='white',ec='k',ax=ax)
    # get attributes
    lat = workplace_cluster.loc[i,"latitude"]
    lon = workplace_cluster.loc[i,"longitude"]
    node_id = workplace_cluster.loc[i,"node_ID"]
    # plot isochrone
    drive_route_times = driving.get_shortest_path_driving(G_car,orig = node_id,dest=None,cbar=cbar,ax=ax)
    # save drive route times 
    # utils.pickle_data(drive_route_times,os.path.join(iso_dir,f'dry_isochrone_car_workClusters{i}.pkl'))
    # plot orig node
    ax.scatter(lon,lat,marker="X",c="r",s=25)
# plt.tight_layout()
# plot colorbar
fig.subplots_adjust(bottom=0.2)
cbar_ax = fig.add_axes([0.15, 0.15, 0.75, 0.01]) # left, bottom, width, height
fig.colorbar(cbar, cax=cbar_ax, orientation='horizontal', label='Travel time (seconds)')
fp_save = os.path.join(iso_dir,"dry_isochrone_car_workClusters.png")
plt.savefig(fp_save, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# # Shortest path - public transport
# - use OneMap API to do public transit routing from origin to destination
# - simulate routing from all bus stop nodes to workplace clusters
# - We need to create a road network for bus that reflects the bus speed limits - `bus_network`
# - OD routing only needs to consider bus stops as D instead of every node in Singapore, as this is the final public transit for most places, don't need to consider walking in the OD journey, as pedestrians will not be affected by floods
# - TODO:
#     - modify `G_car` to `G_bus`. e.g. expressway = 70 - 90 km/h for cars; 60 km/h for buses
#     - save all the routes from OD and its associated nodes **from bus routes only**. The assumption is that bus routes will only be affected by floods, walking and mrt transport will not be affected by floods too much. I guess we are not considering the impact of rains on mrt transport because we cannot prevent intense rainfall, but we can prevent intense floods

# %% [markdown]
# ### G_bus

# %%
save_dir = os.path.join(os.getcwd(),"data")

filename = "SG_car_network.graphml"

G_bus = ox.load_graphml(os.path.join(save_dir,filename))

# %%
edges = ox.graph_to_gdfs(G_bus, nodes=False)
edges.head()
# Out:
#                                                                      osmid  \
# u        v          key
# 25451929 6749812859 0    [49961799, 718881456, 741164883, 754786742, 17...
# 25455287 1637003462 0                                            150829205
#          2521018789 0                     [633215386, 74607482, 635109319]
# 26777521 172424179  0                    [481674707, 654734557, 633179143]
#          1889379421 0         [643413273, 559564482, 640203517, 640203518]
#
#                                highway   lanes maxspeed  \
# u        v          key
# 25451929 6749812859 0         motorway       5     70.0
# 25455287 1637003462 0    motorway_link       1     50.0
#          2521018789 0         motorway  [2, 3]     90.0
# 26777521 172424179  0          primary       2     40.0
#          1889379421 0      residential       2     50.0
#
#                                                   name  oneway  ref reversed  \
# u        v          key
# 25451929 6749812859 0               East Coast Parkway    True  ECP    False
# 25455287 1637003462 0    Kallang Paya Lebar Expressway    True  NaN    False
#          2521018789 0               East Coast Parkway    True  ECP    False
# 26777521 172424179  0                      Grange Road    True  NaN    False
#          1889379421 0                    Cuscaden Road   False  NaN    False
#
#                              length bridge  \
# u        v          key
# 25451929 6749812859 0    765.027747    yes
# 25455287 1637003462 0    629.055082    NaN
#          2521018789 0    652.575579    NaN
# 26777521 172424179  0    113.995770    NaN
#          1889379421 0     86.667744    NaN
#
#                                                                   geometry  \
# u        v          key
# 25451929 6749812859 0    LINESTRING (103.87254 1.29523, 103.87103 1.295...
# 25455287 1637003462 0    LINESTRING (103.874 1.29544, 103.87413 1.2955,...
#          2521018789 0    LINESTRING (103.874 1.29544, 103.87438 1.29544...
# 26777521 172424179  0    LINESTRING (103.82357 1.30398, 103.82359 1.303...
#          1889379421 0    LINESTRING (103.82357 1.30398, 103.82372 1.304...
#
#                          speed_kph  travel_time tunnel junction access width
# u        v          key
# 25451929 6749812859 0         70.0    39.344284    NaN      NaN    NaN   NaN
# 25455287 1637003462 0         50.0    45.291966    NaN      NaN    NaN   NaN
#          2521018789 0         90.0    26.103023    NaN      NaN    NaN   NaN
# 26777521 172424179  0         40.0    10.259619    NaN      NaN    NaN   NaN
#          1889379421 0         50.0     6.240078    NaN      NaN    NaN   NaN

# %%
# if speed exceeds 60, replace it with 60 as that is the maximum bus speed
get_max_bus_speeds = lambda x: 60 if float(x) > 60 else float(x)
edges['maxspeed'] = edges['maxspeed'].apply(get_max_bus_speeds)
edges['maxspeed']
# Out:
# u            v            key
# 25451929     6749812859   0      60.0
# 25455287     1637003462   0      50.0
#              2521018789   0      60.0
# 26777521     172424179    0      40.0
#              1889379421   0      50.0
#                                  ...
# 12288359624  12000390417  0      50.0
# 12288359644  12288359645  0      50.0
#              12000390417  0      40.0
# 12288359645  6777818464   0      40.0
#              12000390427  0      50.0
# Name: maxspeed, Length: 45756, dtype: float64

# %% [markdown]
# ### Replace maxspeed attributes with the updated one (G_bus)

# %%
print('Does the number of edges match? ',len(G_bus.edges()) == len(edges.index))
for (_, _, _, data),maxspeed in zip(G_bus.edges(data=True, keys=True),edges['maxspeed']):
    data['maxspeed'] = maxspeed
# Out:
# Does the number of edges match?  True

# %% [markdown]
# ### Visualise roads' maxspeed limit (G_bus)

# %%
# get node colors by linearly mapping an attribute's values to a colormap
ec = ox.plot.get_edge_colors_by_attr(G_bus, attr="maxspeed", cmap='plasma',num_bins=5)
# fig, ax = ox.plot_graph(G_bus, node_size=0, edge_color=ec, bgcolor="white")
# plot the graph with colored edges
fig, ax = ox.plot_graph(G_bus, node_size=0, edge_color=ec)

# %%
ec_colors = pd.concat([edges['maxspeed'],ec],axis=1).groupby(0)['maxspeed'].apply(lambda x: f'{x.min()}-{x.max()} km/h').reset_index()
print(ec_colors)
# hex colors are stored in the column 0, maxspeed labels are stored in the column maxspeed
plot_utils.plot_colortable(ec_colors[0], ec_colors['maxspeed'], ncols=3, sort_colors=False)
# Out:
#          0        maxspeed
# 0  #0d0887  10.0-20.0 km/h
# 1  #7e03a8  25.0-30.0 km/h
# 2  #cc4778  40.0-40.0 km/h
# 3  #f0f921  60.0-60.0 km/h
# 4  #f89540  50.0-50.0 km/h

# %% [markdown]
# ### Add edge travel times (G_bus)

# %%
# impute speed on all edges missing data
G_bus = ox.add_edge_speeds(G_bus)

# calculate travel time (seconds) for all edges
G_bus = ox.add_edge_travel_times(G_bus)

# %% [markdown]
# ### Export bus network
#
# with the updated max speed limit

# %%
# # # # save walking network
save_dir = os.path.join(os.getcwd(),"data")
# # if not os.path.exists(save_dir):
# #     os.mkdir(save_dir)
filename = "SG_bus_network.graphml"
# # # save graph to disk as GraphML file
# ox.save_graphml(G_bus, filepath=os.path.join(save_dir,filename))

G_bus = ox.load_graphml(os.path.join(save_dir,filename))

# %%
# get node colors by linearly mapping an attribute's values to a colormap
ec = ox.plot.get_edge_colors_by_attr(G_bus, attr="speed_kph", cmap='plasma',num_bins=5)
# fig, ax = ox.plot_graph(G_bus, node_size=0, edge_color=ec, bgcolor="white")
# plot the graph with colored edges
fig, ax = ox.plot_graph(G_bus, node_size=0, edge_color=ec)

# %% [markdown]
# ### Import gtfs shapes and bus stops

# %%
GTFS_shapes = pd.read_csv(r"C:\Users\hypak\OneDrive - Singapore Management University\Documents\Data\SG_LTA\gtfs-feed-lta\shapes.txt")
GTFS_stops = pd.read_csv(r"C:\Users\hypak\OneDrive - Singapore Management University\Documents\Data\SG_LTA\gtfs-feed-lta\stops.txt")
print(f'Length of shapes: {GTFS_shapes.shape[0]}')
print(f'Length of stops: {GTFS_stops.shape[0]}')
GTFS_stops.head()
# Out:
# Length of shapes: 68842
# Length of stops: 5251
#   stop_code stop_id  stop_lat    stop_lon            stop_name  \
# 0     01012   01012  1.296848  103.852536  Hotel Grand Pacific
# 1     01013   01013  1.297710  103.853225      St. Joseph's Ch
# 2     01019   01019  1.296990  103.853022      Bras Basah Cplx
# 3     01029   01029  1.296673  103.854414         Opp Natl Lib
# 4     01039   01039  1.298208  103.855491           Bugis Cube
#
#                              stop_url  wheelchair_boarding
# 0  https://busrouter.sg/#/stops/01012                    1
# 1  https://busrouter.sg/#/stops/01013                    1
# 2  https://busrouter.sg/#/stops/01019                    1
# 3  https://busrouter.sg/#/stops/01029                    1
# 4  https://busrouter.sg/#/stops/01039                    1

# %% [markdown]
# ### Import workplace clusters

# %%
workplace_cluster = pd.read_csv(r"data\workplace_cluster.csv")
workplace_cluster
workplace_nodes = ox.distance.nearest_nodes(G_bus, X=workplace_cluster.longitude.to_list(), Y=workplace_cluster.latitude.to_list())
workplace_nodes
workplace_cluster['node_ID'] = workplace_nodes
workplace_cluster
# Out:
#     latitude   longitude     node_ID
# 0   1.320935  103.894151   258305981
# 1   1.327584  103.703464  4494048581
# 2   1.448092  103.810287  4607055587
# 3   1.284441  103.842959   246800416
# 4   1.295068  103.629310   842360753
# 5   1.356448  103.957308  4602456624
# 6   1.299561  103.798223  4229611568
# 7   1.309864  103.857340  7144522951
# 8   1.374454  103.857601  6247137952
# 9   1.320213  103.656895   310231673
# 10  1.415385  103.751913   243998823
# 11  1.326087  103.753416  4602603057

# %% [markdown]
# # Export public transit routing

# %% [markdown]
# ### Get OneMap token

# %%
headers = publicTransit.generate_OneMap_token()

# %%
save_dir = r"D:\PAKHUIYING\publicTransit_busRouting"
noData_file = os.path.join(r'data','busRoutingError3.txt')
for workplace_ix, workplace_rows in workplace_cluster.loc[10:,:].iterrows():
    for gtfs_ix, gtfs_rows in GTFS_stops.loc[3528:,:].iterrows():
        
        # origin coords and origin key
        busStop_coords = (gtfs_rows['stop_lat'],gtfs_rows['stop_lon'])
        busStop_key = gtfs_rows['stop_id']
        # destination coords and destination key
        workplace_coords = (workplace_rows['latitude'], workplace_rows['longitude'])
        workplace_key = int(workplace_rows['node_ID'])
        # save_fp
        save_fp = os.path.join(save_dir,f'{busStop_key}to{workplace_key}.json')
        # export data
        try:
            itinerary = publicTransit.public_transit_routing(busStop_coords, busStop_key, 
                                            workplace_coords, workplace_key,
                            G_bus, GTFS_shapes, headers,
                                plot = False,
                                save_fp = save_fp)
        except:
            # export data that has an error
            print(f'{gtfs_ix}:{busStop_key},{workplace_ix}:{workplace_key}')
            if not os.path.exists(noData_file):
                with open(noData_file, "w") as myfile:
                    myfile.write(f'{gtfs_ix}:{busStop_key},{workplace_ix}:{workplace_key}\n')

            else:
                with open(noData_file, "a") as myfile:
                    myfile.write(f'{gtfs_ix}:{busStop_key},{workplace_ix}:{workplace_key}\n')

        # break
# Out:
# 3644:65371,10:243998823
# 3649:65399,10:243998823
# 3651:65409,10:243998823
# 3656:65439,10:243998823
# 3684:65629,10:243998823
# 3687:65641,10:243998823
# 3688:65651,10:243998823
# 3692:65681,10:243998823
# 3693:65689,10:243998823
# 3800:67041,10:243998823
# 3809:67089,10:243998823
# 3845:67281,10:243998823
243998823
# Token may have expired, input new headers: 'plan'
# Token may have expired, input new headers: 'plan'
# 5205:CC26,10:243998823
# 3609:65171,11:4602603057
# 3611:65181,11:4602603057
# 3612:65189,11:4602603057
# 3620:65231,11:4602603057
# 3621:65239,11:4602603057
# 3623:65249,11:4602603057
# 3629:65279,11:4602603057
# 3637:65329,11:4602603057
# 3644:65371,11:4602603057
# 3645:65379,11:4602603057
# 3652:65411,11:4602603057
# 3653:65419,11:4602603057
# 3654:65429,11:4602603057
# 3669:65531,11:4602603057
# 3670:65539,11:4602603057
# 3671:65541,11:4602603057
# 3672:65549,11:4602603057
# 3674:65559,11:4602603057
# 3675:65561,11:4602603057
# 3676:65569,11:4602603057
# 3692:65681,11:4602603057
# 3693:65689,11:4602603057
# Token may have expired, input new headers: 'plan'
# Token may have expired, input new headers: 'plan'
# Token may have expired, input new headers: 'plan'
# Token may have expired, input new headers: 'plan'
# 3864:67379,11:4602603057
# Token may have expired, input new headers: 'plan'
# 3899:67551,11:4602603057
# 3901:67561,11:4602603057
# 3920:67691,11:4602603057
# 3921:67699,11:4602603057
# 3931:67761,11:4602603057
# 3966:68191,11:4602603057
# 3967:68199,11:4602603057
# 4117:75021,11:4602603057
# 4121:75059,11:4602603057
# 4143:75179,11:4602603057
# 4177:75401,11:4602603057
# 4178:75409,11:4602603057
# 4180:75419,11:4602603057
# 4195:76041,11:4602603057
# 4196:76049,11:4602603057
# 4200:76069,11:4602603057
# 4209:76111,11:4602603057
# 4300:77091,11:4602603057
# 4317:77199,11:4602603057
# 4321:77219,11:4602603057
# 4332:77279,11:4602603057
# 4344:77341,11:4602603057
# 4346:77351,11:4602603057
# 4347:77359,11:4602603057
# 4348:77361,11:4602603057
# 4349:77369,11:4602603057
# 4379:78171,11:4602603057
# 4380:78179,11:4602603057
# 4576:84041,11:4602603057
# 4601:84199,11:4602603057
# 4604:84211,11:4602603057
# 4606:84221,11:4602603057
# 4733:91099,11:4602603057
# 4815:93169,11:4602603057
# 4817:93179,11:4602603057
# 4822:94009,11:4602603057
# Token may have expired, input new headers: 'plan'
# Token may have expired, input new headers: 'plan'
# 4842:95039,11:4602603057
# 4843:95041,11:4602603057
# Token may have expired, input new headers: 'plan'
# Token may have expired, input new headers: 'plan'
# 4844:95049,11:4602603057
# 4845:95051,11:4602603057
# 4846:95061,11:4602603057
# 4847:95069,11:4602603057
# 4848:95071,11:4602603057
# 4850:95081,11:4602603057
# 4851:95089,11:4602603057
# 4852:95091,11:4602603057
# 4853:95099,11:4602603057
# 4856:95131,11:4602603057
# 4857:95139,11:4602603057
# 4858:95141,11:4602603057
# 4859:95149,11:4602603057
# 4864:95171,11:4602603057
# 4866:95181,11:4602603057
# 4867:95189,11:4602603057
# 4868:95191,11:4602603057
# Token may have expired, input new headers: 'plan'
# Token may have expired, input new headers: 'plan'
# 4944:96421,11:4602603057
# Token may have expired, input new headers: 'plan'
# Token may have expired, input new headers: 'plan'
# 4945:96429,11:4602603057
# Token may have expired, input new headers: 'plan'
# Token may have expired, input new headers: 'plan'
# 4946:96431,11:4602603057
# Token may have expired, input new headers: 'plan'
# Token may have expired, input new headers: 'plan'
# 4947:96439,11:4602603057
# 5118:PE4,11:4602603057
# 5149:DT21,11:4602603057

# %% [markdown]
# ### Correct json error that couldnt load properly because of encoding error

# %%
busroutes_dir = r"D:\PAKHUIYING\publicTransit_busRouting"
error_fp = [os.path.join(busroutes_dir,fp) for fp in os.listdir(busroutes_dir) if fp.endswith('_ERROR.json')]
print(f'Number of error files: {len(error_fp)}')
# Out:
# Number of error files: 660

# %%
GTFS_missingBusServices = utils.load_txt(os.path.join(r'data','GTFS_missingBusServices.txt'))
GTFS_shortenedBusServices = utils.load_pickle(os.path.join(r'data','GTFS_shortenedBusServices.pkl'))

# %%
GTFS_shapes_new = os.path.join(r"C:\Users\hypak\OneDrive - Singapore Management University\Documents\Data\SG_LTA",
                                       "GTFS_shapes_3Mar2025.csv")
GTFS_shapes_new = pd.read_csv(GTFS_shapes_new)
# len(GTFS_shapes.index)
len(GTFS_shapes_new.index)
GTFS_shapes_new
# Out:
#              shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence
# 0          BP.0_shape      1.384749    103.744534                  1
# 1          BP.0_shape      1.380260    103.745285                  2
# 2          BP.0_shape      1.378599    103.749030                  3
# 3          BP.0_shape      1.376670    103.753647                  4
# 4          BP.0_shape      1.378616    103.758008                  5
# ...               ...           ...           ...                ...
# 69836  993:WD:0_shape      1.342390    103.735989                 21
# 69837  993:WD:0_shape      1.340164    103.736346                 22
# 69838  993:WD:0_shape      1.338399    103.738601                 23
# 69839  993:WD:0_shape      1.336182    103.739445                 24
# 69840  993:WD:0_shape      1.332350    103.740665                 25
#
# [69841 rows x 4 columns]

# %%
GTFS_shapes[GTFS_shapes['shape_id'].str.contains(f"^913T:WD")].sort_values('shape_pt_sequence')
# Out:
# Empty DataFrame
# Columns: [shape_id, shape_pt_lat, shape_pt_lon, shape_pt_sequence]
# Index: []

# %%
# import one itinerary
itinerary = utils.load_json(r"D:\PAKHUIYING\publicTransit_busRouting\65009to243998823.json")
itinerary
# Out:
# {'busStart': [1.40370629859822, 103.90224337575332, '65009'],
#  'workEnd': [1.4153853911798833, 103.75191334192226, 243998823],
#  'duration': 5858,
#  'startTime': 1738713750000,
#  'endTime': 1738719608000,
#  'transitTime': 4025,
#  'waitingTime': 607,
#  'transfers': 2,
#  'busLegs': [{'leg_number': 0,
#    'duration': 724,
#    'distance': 4255.31,
#    'startTime': 1738713750000,
#    'endTime': 1738714474000,
#    'tripId': '117-1-1009',
#    'tripDirection': 0,
#    'mode': 'BUS',
#    'routeId': '117',
#    'legGeometry': {'points': 'edqGgldyRl@IjAiCbCnAVLvAt@pAn@Ob@e@lAq@hB????Ul@aAnDQr@IVGTWbA[pAEJ????k@`CYzBDf@Rf@\\XnBT??fAJnCZbDn@PDPFv@RvA`@d@J[xByCzNm@hH{@~Lc@rIUjGI|DI`F?hA?~A?J@`BX~f@~AxSAbAW@mA@kA@}@LOLGNAPHjAGJQJa@@',
#     'length': 63},
#    'busLeg': [{'name': 'PUNGGOL TEMP INT',
#      'stopId': 'FERRY:65009',
#      'stopCode': '65009',
#      'lon': 103.9022434,
#      'lat': 1.4037063,
#      'departure': 1738713750000,
#      'stopIndex': 0,
#      'stopSequence': 1,
#      'vertexType': 'TRANSIT',
#      'arrival': nan},
#     {'name': 'OPP BLK 272C',
#      'stopId': 'FERRY:65341',
#      'stopCode': '65341',
#      'lon': 103.900923,
#      'lat': 1.4019469,
#      'departure': 1738713866000,
#      'stopIndex': 1,
#      'stopSequence': 2,
#      'vertexType': 'TRANSIT',
#      'arrival': 1738713836000.0},
#     {'name': 'OPP BLK 268D',
#      'stopId': 'FERRY:65331',
#      'stopCode': '65331',
#      'lon': 103.8985181,
#      'lat': 1.402865,
#      'departure': 1738713940000,
#      'stopIndex': 2,
#      'stopSequence': 3,
#      'vertexType': 'TRANSIT',
#      'arrival': 1738713910000.0},
#     {'name': 'TWIN WATERFALLS',
#      'stopId': 'FERRY:65431',
#      'stopCode': '65431',
#      'lon': 103.8967356,
#      'lat': 1.4023894,
#      'departure': 1738714013000,
#      'stopIndex': 3,
#      'stopSequence': 4,
#      'vertexType': 'TRANSIT',
#      'arrival': 1738713983000.0},
#     {'name': 'BEF SELETAR CAMP G',
#      'stopId': 'FERRY:68111',
#      'stopCode': '68111',
#      'lon': 103.8713881,
#      'lat': 1.4022219,
#      'departure': 1738714474000,
#      'stopIndex': 4,
#      'stopSequence': 5,
#      'vertexType': 'TRANSIT',
#      'arrival': 1738714474000.0}],
#    'gtfs': [{'shape_id': '117:WD:0_shape',
#      'shape_pt_lat': 1.40370629859822,
#      'shape_pt_lon': 103.90224337575332,
#      'shape_pt_sequence': 1},
#     {'shape_id': '117:WD:0_shape',
#      'shape_pt_lat': 1.405351944,
#      'shape_pt_lon': 103.9018719,
#      'shape_pt_sequence': 2},
#     {'shape_id': '117:WD:0_shape',
#      'shape_pt_lat': 1.40624496856359,
#      'shape_pt_lon': 103.89957451783918,
#      'shape_pt_sequence': 3},
#     {'shape_id': '117:WD:0_shape',
#      'shape_pt_lat': 1.40454805557377,
#      'shape_pt_lon': 103.89716388800268,
#      'shape_pt_sequence': 4},
#     {'shape_id': '117:WD:0_shape',
#      'shape_pt_lat': 1.40238938083661,
#      'shape_pt_lon': 103.89673562171808,
#      'shape_pt_sequence': 5}],
#    'routesNodesID': [4598671888,
#     4427352186,
#     4427352394,
#     4598672229,
#     2274884591,
#     368899632,
#     1748996424,
#     4430972624,
#     4004994591,
#     368921576,
#     411679973,
#     4598834586,
#     3600777293]},
#   {'leg_number': 1,
#    'duration': 2093,
#    'distance': 13735.84,
#    'startTime': 1738714818000,
#    'endTime': 1738716911000,
#    'tripId': '168-1-1010',
#    'tripDirection': 0,
#    'mode': 'BUS',
#    'routeId': '168',
#    'legGeometry': {'points': 'i{pGmn~xR??PIPWLSLK\\Gb@AT@jAAlAAVAE~@MfE?v@?t@HdCJvAFlAL~BC`ESfHI~EEdCWpCL~QNpCLxAXxBt@lDj@fBt@xAtBxDvBzC`@h@j@h@vDlD~@nAn@pAf@bBV~A?NN|EAjEY|FUdPDvEPvE\\bFd@hEr@nFlCrPfAxGhEjW|@lFf@`DZ~CXrCLtBJlDAjHWfGc@xFaAvGk@dDkExS]bBaAtCeArBmA|AwAlA_BhAuB`A_Cp@iHdBgJ|CaGjCcDjBuDhCqGzEkFpCiFpBuGjB}RnFaDbAmChAwCfBqBjBkBnBgAnAeAlAsCtDiB~B{C`E{EzGaDpFyF`M{CxG}D~IcEfJ{AjEgA|D}@fEg@~CUxDBrBF^L^\\`@VJTDZ?bASRWNa@Ba@Kg@QYQQWOUKa@KoL{AuDi@_HgA????kGcAWC{AYa@IYGeASWEmCa@??gCa@q@K_AQ]Ii@Kq@Ok@IyGcA??????C?gAE{@BW@[^EL?\\p@bCp@jC\\lA',
#     'length': 157},
#    'busLeg': [{'name': 'AFT SELETAR CAMP G',
#      'stopId': 'FERRY:68119',
#      'stopCode': '68119',
#      'lon': 103.8719487,
#      'lat': 1.4023131,
#      'arrival': 1738714590000,
#      'departure': 1738714818000,
#      'stopIndex': 21,
#      'stopSequence': 22,
#      'vertexType': 'TRANSIT'},
#     {'name': 'CASABLANCA',
#      'stopId': 'FERRY:46229',
#      'stopCode': '46229',
#      'lon': 103.7870687,
#      'lat': 1.4301306,
#      'arrival': 1738716648000,
#      'departure': 1738716678000,
#      'stopIndex': 22,
#      'stopSequence': 24,
#      'vertexType': 'TRANSIT'},
#     {'name': "BEF W'LANDS STN EXIT 7",
#      'stopId': 'FERRY:46339',
#      'stopCode': '46339',
#      'lon': 103.7879832,
#      'lat': 1.4335263,
#      'arrival': 1738716736000,
#      'departure': 1738716766000,
#      'stopIndex': 23,
#      'stopSequence': 25,
#      'vertexType': 'TRANSIT'},
#     {'name': "W'LANDS STN EXIT 4",
#      'stopId': 'FERRY:46639',
#      'stopCode': '46639',
#      'lon': 103.7888492,
#      'lat': 1.4370221,
#      'arrival': 1738716823000,
#      'departure': 1738716853000,
#      'stopIndex': 24,
#      'stopSequence': 26,
#      'vertexType': 'TRANSIT'},
#     {'name': 'WOODLANDS INT',
#      'stopId': 'FERRY:46009',
#      'stopCode': '46009',
#      'lon': 103.7868962,
#      'lat': 1.4372353,
#      'arrival': 1738716911000,
#      'departure': 1738717290000,
#      'stopIndex': 25,
#      'stopSequence': 27,
#      'vertexType': 'TRANSIT'}],
#    'gtfs': [{'shape_id': '168:WD:0_shape',
#      'shape_pt_lat': 1.43352632033198,
#      'shape_pt_lon': 103.78798319246935,
#      'shape_pt_sequence': 24},
#     {'shape_id': '168:WD:0_shape',
#      'shape_pt_lat': 1.43702205360453,
#      'shape_pt_lon': 103.78884919678752,
#      'shape_pt_sequence': 25},
#     {'shape_id': '168:WD:0_shape',
#      'shape_pt_lat': 1.436874,
#      'shape_pt_lon': 103.786162,
#      'shape_pt_sequence': 26}],
#    'routesNodesID': [1110929778,
#     2577844043,
#     4606947582,
#     4740186508,
#     6170309593,
#     1111079996,
#     4010403789,
#     7177379508,
#     1111080132]},
#   {'leg_number': 2,
#    'duration': 1208,
#    'distance': 5826.49,
#    'startTime': 1738717290000,
#    'endTime': 1738718498000,
#    'tripId': '960-1-2004',
#    'tripDirection': 0,
#    'mode': 'BUS',
#    'routeId': '960',
#    'legGeometry': {'points': 'cvwG}zmxRpCjK`AWbA[L?JJhAbEPbAHj@Cn@??HJBDh@z@FF~@~@LLJJHFbDdD~@pA??????^h@nAhCf@~ANp@FZDVTfBHfB??@dO?nE??@hF@^Bv@@XB\\HhALfA????d@tEV`Bd@|Df@hBf@jBfArB`@`@r@n@z@j@jD`BJF????b@V|@v@RPLLTXl@`AtBdFVf@xAvBp@`AX^RZNRz@jAZd@TZ\\d@|@lA????j@t@x@xAdAjBr@bBVbAf@~CF^??f@tCVfANh@J^Zn@@@j@p@r@^VP\\NfAd@JFx@`@??fFbCjDjA@?nCP`@D@?`@?`@?hAFhA?????|EAl@CNA|CI~Be@nBu@~CuAt@Q????x@OlACdB@Z@pB?`@@nBFvCHv@CXC????xD]fCUl@GhAItAE',
#     'length': 139},
#    'busLeg': [{'name': 'WOODLANDS INT',
#      'stopId': 'FERRY:46009',
#      'stopCode': '46009',
#      'lon': 103.7868962,
#      'lat': 1.4372353,
#      'arrival': 1738716911000,
#      'departure': 1738717290000,
#      'stopIndex': 0,
#      'stopSequence': 1,
#      'vertexType': 'TRANSIT'},
#     {'name': 'BLK 347',
#      'stopId': 'FERRY:46549',
#      'stopCode': '46549',
#      'lon': 103.7812567,
#      'lat': 1.4331982,
#      'arrival': 1738717420000,
#      'departure': 1738717450000,
#      'stopIndex': 1,
#      'stopSequence': 2,
#      'vertexType': 'TRANSIT'},
#     {'name': 'BLK 320',
#      'stopId': 'FERRY:46539',
#      'stopCode': '46539',
#      'lon': 103.7782237,
#      'lat': 1.4320996,
#      'arrival': 1738717507000,
#      'departure': 1738717537000,
#      'stopIndex': 2,
#      'stopSequence': 3,
#      'vertexType': 'TRANSIT'},
#     {'name': 'OPP MARSILING STN',
#      'stopId': 'FERRY:46529',
#      'stopCode': '46529',
#      'lon': 103.7745969,
#      'lat': 1.4320815,
#      'arrival': 1738717595000,
#      'departure': 1738717625000,
#      'stopIndex': 3,
#      'stopSequence': 4,
#      'vertexType': 'TRANSIT'},
#     {'name': 'BLK 402',
#      'stopId': 'FERRY:46491',
#      'stopCode': '46491',
#      'lon': 103.772008,
#      'lat': 1.4318897,
#      'arrival': 1738717668000,
#      'departure': 1738717698000,
#      'stopIndex': 4,
#      'stopSequence': 5,
#      'vertexType': 'TRANSIT'},
#     {'name': "OPP W'LANDS IND PK D ST 1",
#      'stopId': 'FERRY:46381',
#      'stopCode': '46381',
#      'lon': 103.7667627,
#      'lat': 1.4290743,
#      'arrival': 1738717799000,
#      'departure': 1738717829000,
#      'stopIndex': 5,
#      'stopSequence': 6,
#      'vertexType': 'TRANSIT'},
#     {'name': 'KRANJI STN',
#      'stopId': 'FERRY:45139',
#      'stopCode': '45139',
#      'lon': 103.761781,
#      'lat': 1.4252596,
#      'arrival': 1738717930000,
#      'departure': 1738717960000,
#      'stopIndex': 6,
#      'stopSequence': 7,
#      'vertexType': 'TRANSIT'},
#     {'name': 'KF1 KARTING CIRCUIT',
#      'stopId': 'FERRY:45129',
#      'stopCode': '45129',
#      'lon': 103.7586346,
#      'lat': 1.4238293,
#      'arrival': 1738718017000,
#      'departure': 1738718047000,
#      'stopIndex': 7,
#      'stopSequence': 8,
#      'vertexType': 'TRANSIT'},
#     {'name': 'KRANJI WAR MEMORIAL',
#      'stopId': 'FERRY:45119',
#      'stopCode': '45119',
#      'lon': 103.7559773,
#      'lat': 1.4218135,
#      'arrival': 1738718105000,
#      'departure': 1738718135000,
#      'stopIndex': 8,
#      'stopSequence': 9,
#      'vertexType': 'TRANSIT'},
#     {'name': 'BEF JLN BUMBONG',
#      'stopId': 'FERRY:45109',
#      'stopCode': '45109',
#      'lon': 103.7547803,
#      'lat': 1.417858,
#      'arrival': 1738718207000,
#      'departure': 1738718237000,
#      'stopIndex': 9,
#      'stopSequence': 10,
#      'vertexType': 'TRANSIT'},
#     {'name': 'AFT JLN BUMBONG',
#      'stopId': 'FERRY:45099',
#      'stopCode': '45099',
#      'lon': 103.7559131,
#      'lat': 1.4134173,
#      'arrival': 1738718309000,
#      'departure': 1738718339000,
#      'stopIndex': 10,
#      'stopSequence': 11,
#      'vertexType': 'TRANSIT'},
#     {'name': 'AFT MANDAI RD',
#      'stopId': 'FERRY:45079',
#      'stopCode': '45079',
#      'lon': 103.755882,
#      'lat': 1.4095935,
#      'arrival': 1738718396000,
#      'departure': 1738718426000,
#      'stopIndex': 11,
#      'stopSequence': 12,
#      'vertexType': 'TRANSIT'},
#     {'name': 'AFT MANDAI EST',
#      'stopId': 'FERRY:45069',
#      'stopCode': '45069',
#      'lon': 103.7562677,
#      'lat': 1.4069391,
#      'arrival': 1738718498000,
#      'departure': 1738718498000,
#      'stopIndex': 12,
#      'stopSequence': 13,
#      'vertexType': 'TRANSIT'}],
#    'gtfs': [{'shape_id': '960:WD:0_shape',
#      'shape_pt_lat': 1.436874,
#      'shape_pt_lon': 103.786162,
#      'shape_pt_sequence': 1},
#     {'shape_id': '960:WD:0_shape',
#      'shape_pt_lat': 1.43319818915334,
#      'shape_pt_lon': 103.7812567265195,
#      'shape_pt_sequence': 2},
#     {'shape_id': '960:WD:0_shape',
#      'shape_pt_lat': 1.43209962904173,
#      'shape_pt_lon': 103.7782236553492,
#      'shape_pt_sequence': 3},
#     {'shape_id': '960:WD:0_shape',
#      'shape_pt_lat': 1.43208152770031,
#      'shape_pt_lon': 103.77459689006626,
#      'shape_pt_sequence': 4},
#     {'shape_id': '960:WD:0_shape',
#      'shape_pt_lat': 1.43188974761143,
#      'shape_pt_lon': 103.77200799456398,
#      'shape_pt_sequence': 5},
#     {'shape_id': '960:WD:0_shape',
#      'shape_pt_lat': 1.42907427878851,
#      'shape_pt_lon': 103.76676266569542,
#      'shape_pt_sequence': 6},
#     {'shape_id': '960:WD:0_shape',
#      'shape_pt_lat': 1.42525961270458,
#      'shape_pt_lon': 103.76178101875855,
#      'shape_pt_sequence': 7},
#     {'shape_id': '960:WD:0_shape',
#      'shape_pt_lat': 1.42382925070118,
#      'shape_pt_lon': 103.75863462427267,
#      'shape_pt_sequence': 8},
#     {'shape_id': '960:WD:0_shape',
#      'shape_pt_lat': 1.42181345656216,
#      'shape_pt_lon': 103.7559772935124,
#      'shape_pt_sequence': 9},
#     {'shape_id': '960:WD:0_shape',
#      'shape_pt_lat': 1.41785797439114,
#      'shape_pt_lon': 103.75478033541316,
#      'shape_pt_sequence': 10},
#     {'shape_id': '960:WD:0_shape',
#      'shape_pt_lat': 1.41341731294698,
#      'shape_pt_lon': 103.75591307485898,
#      'shape_pt_sequence': 11},
#     {'shape_id': '960:WD:0_shape',
#      'shape_pt_lat': 1.40959346067748,
#      'shape_pt_lon': 103.75588199006808,
#      'shape_pt_sequence': 12},
#     {'shape_id': '960:WD:0_shape',
#      'shape_pt_lat': 1.4069390779681,
#      'shape_pt_lon': 103.75626773948964,
#      'shape_pt_sequence': 13}],
#    'routesNodesID': [7177379508,
#     1111080132,
#     1852876997,
#     4010399788,
#     1110929661,
#     1110929638,
#     1110672343,
#     4926676212,
#     4740372592,
#     6112923443,
#     1110672350,
#     6673753666,
#     244322210,
#     1110331456,
#     1110331660,
#     1110331764,
#     1110331455,
#     890376930,
#     890376935,
#     890376936,
#     890376937,
#     244372733,
#     236727852,
#     244372744,
#     5087750451,
#     1474198027,
#     236727524,
#     243986818,
#     1972010039,
#     4740239367,
#     4745145694,
#     4745145695,
#     313928674,
#     4745180248,
#     4604216182,
#     1884168718,
#     5278383732,
#     1867527388,
#     4604203472,
#     2377899657,
#     236727793,
#     5272396527]}]}

# %%
# plot test itinerary
fig, ax = ox.plot_graph_route(G_bus,itinerary['busLegs'][0]['routesNodesID'], node_size=0,show=False,close=False)
lats = np.array([itinerary['busStart'][0], itinerary['workEnd'][0]])
lons = np.array([itinerary['busStart'][1], itinerary['workEnd'][1]])

min_lat, max_lat, delta_lat, min_lon, max_lon, delta_lon = publicTransit.get_bus_lims(lats,lons)
print(min_lat, max_lat, delta_lat, min_lon, max_lon, delta_lon)
ylim_factor = 0.1
xlim_factor = 0.4
ax.set_ylim(min_lat-ylim_factor*delta_lat,max_lat+ylim_factor*delta_lat)
ax.set_xlim(min_lon-xlim_factor*delta_lon,max_lon+xlim_factor*delta_lon)
# Out:
# 1.31471795031338 1.4480919633081966 0.13337401299481666 103.81028707234208 103.8637679549332 0.05348088259111705
# (103.78889471930563, 103.88516030796964)

# %%
publicTransit.get_OneMap_itineraries(headers=headers,
                                    start_lat = 1.297506,
                                    start_lon = 103.777154,
                                    end_lat = 1.355851,
                                    end_lon= 103.691928,
                                    route_type = "pt" ,
                                    date = '01-13-2025',
                                    time = '07%3A35%3A00' ,
                                    mode = 'TRANSIT' ,
                                    maxWalkDistance = '1000' ,
                                    numItineraries = '3'
                                    )
# Out:
# [{'duration': 3114,
#   'startTime': 1736725231000,
#   'endTime': 1736728345000,
#   'walkTime': 773,
#   'transitTime': 1918,
#   'waitingTime': 423,
#   'walkDistance': 815.3,
#   'walkLimitExceeded': False,
#   'generalizedCost': 9651,
#   'elevationLost': 0,
#   'elevationGained': 0,
#   'transfers': 2,
#   'fare': '1.98',
#   'legs': [{'startTime': 1736725231000,
#     'endTime': 1736725717000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 516.15,
#     'generalizedCost': 3403,
#     'pathway': False,
#     'mode': 'WALK',
#     'transitLeg': False,
#     'route': '',
#     'agencyTimeZoneOffset': 28800000,
#     'interlineWithPreviousLeg': False,
#     'from': {'name': 'Origin',
#      'lon': 103.777154,
#      'lat': 1.297506,
#      'departure': 1736725231000,
#      'vertexType': 'NORMAL'},
#     'to': {'name': 'OPP YUSOF ISHAK HSE',
#      'stopId': 'FERRY:16179',
#      'stopCode': '16179',
#      'lon': 103.7741773,
#      'lat': 1.2989816,
#      'arrival': 1736725717000,
#      'departure': 1736725717000,
#      'vertexType': 'TRANSIT'},
#     'legGeometry': {'points': 'kl|Fe~kxROECI@I[QGHSXe@j@UTA@SNOJa@TKLORKNIXCP?@A^Fn@@XGb@G`@GRQ\\GJAB?BB@EN????????@?????@?@?@???@?@A@???@?@???@?@A@???@??@QDSj@ELYr@B@HBPHH@@AJ??@AE??',
#      'length': 68},
#     'steps': [{'distance': 516.16,
#       'relativeDirection': 'DEPART',
#       'streetName': 'path',
#       'absoluteDirection': 'NORTHEAST',
#       'stayOn': False,
#       'area': False,
#       'bogusName': True,
#       'lon': 103.7771582,
#       'lat': 1.2975045,
#       'elevation': '',
#       'walkingBike': False}],
#     'rentedBike': False,
#     'walkingBike': False,
#     'duration': 486},
#    {'startTime': 1736725717000,
#     'endTime': 1736726240000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 2758.65,
#     'generalizedCost': 1120,
#     'pathway': False,
#     'mode': 'BUS',
#     'transitLeg': True,
#     'route': '96',
#     'agencyName': 'Tower Transit Services',
#     'agencyUrl': 'http://towertransit.sg/',
#     'agencyTimeZoneOffset': 28800000,
#     'routeType': 3,
#     'routeId': '96',
#     'interlineWithPreviousLeg': False,
#     'agencyId': '1:TTS',
#     'tripId': '96-1-1011',
#     'serviceDate': '2025-01-13',
#     'from': {'name': 'OPP YUSOF ISHAK HSE',
#      'stopId': 'FERRY:16179',
#      'stopCode': '16179',
#      'lon': 103.7741773,
#      'lat': 1.2989816,
#      'arrival': 1736725717000,
#      'departure': 1736725717000,
#      'stopIndex': 8,
#      'stopSequence': 9,
#      'vertexType': 'TRANSIT'},
#     'to': {'name': 'CLEMENTI STN EXIT A',
#      'stopId': 'FERRY:17171',
#      'stopCode': '17171',
#      'lon': 103.765027,
#      'lat': 1.314974,
#      'arrival': 1736726240000,
#      'departure': 1736726240000,
#      'stopIndex': 13,
#      'stopSequence': 14,
#      'vertexType': 'TRANSIT'},
#     'intermediateStops': [{'name': 'NUS RAFFLES HALL',
#       'stopId': 'FERRY:16169',
#       'stopCode': '16169',
#       'lon': 103.7727042,
#       'lat': 1.3009833,
#       'arrival': 1736725775000,
#       'departure': 1736725805000,
#       'stopIndex': 9,
#       'stopSequence': 10,
#       'vertexType': 'TRANSIT'},
#      {'name': 'AFT CLEMENTI AVE 1',
#       'stopId': 'FERRY:17091',
#       'stopCode': '17091',
#       'lon': 103.7715778,
#       'lat': 1.3090481,
#       'arrival': 1736725963000,
#       'departure': 1736725993000,
#       'stopIndex': 10,
#       'stopSequence': 11,
#       'vertexType': 'TRANSIT'},
#      {'name': 'BLK 410',
#       'stopId': 'FERRY:17151',
#       'stopCode': '17151',
#       'lon': 103.7696099,
#       'lat': 1.3116952,
#       'arrival': 1736726080000,
#       'departure': 1736726110000,
#       'stopIndex': 11,
#       'stopSequence': 12,
#       'vertexType': 'TRANSIT'},
#      {'name': 'BLK 455',
#       'stopId': 'FERRY:17161',
#       'stopCode': '17161',
#       'lon': 103.7668548,
#       'lat': 1.3124099,
#       'arrival': 1736726153000,
#       'departure': 1736726183000,
#       'stopIndex': 12,
#       'stopSequence': 13,
#       'vertexType': 'TRANSIT'}],
#     'legGeometry': {'points': 'gu|FalkxRIGCA{@U[E[ESSYB]?A?g@Hi@Ty@t@s@xAELQp@C\\AL@N@dA????@|@?v@?PKz@GRAJGNOp@]nAGTKZ?@?@EH??CHGCQISKSK_A[SGKEc@KWGOGWEk@MsBSmA?g@?yB?eA@g@@m@AeAAsACuAMo@GyAQeAMUCA?A?s@KWAqB[??E???}@O_@GC?E?E?CAEA[EWAKAMA]A{@MA?sAS}AQYBq@HMFOJKPKPABId@FpA@b@PhDF|@DZ?D???B?@@L?@??@h@?Z?t@Ab@AZIl@Kj@EPG`@EJ?@?BA@CH?@A??@?BCF?@ABMZGVw@|A??A?A@ABED]f@a@h@MJONA@EDQPy@j@mAl@aA`@wAb@oAb@E@A@',
#      'length': 151},
#     'steps': [],
#     'routeShortName': '96',
#     'routeLongName': 'TTS BUS 96',
#     'duration': 523},
#    {'startTime': 1736726240000,
#     'endTime': 1736726336000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 90.41,
#     'generalizedCost': 605,
#     'pathway': False,
#     'mode': 'WALK',
#     'transitLeg': False,
#     'route': '',
#     'agencyTimeZoneOffset': 28800000,
#     'interlineWithPreviousLeg': False,
#     'from': {'name': 'CLEMENTI STN EXIT A',
#      'stopId': 'FERRY:17171',
#      'stopCode': '17171',
#      'lon': 103.765027,
#      'lat': 1.314974,
#      'arrival': 1736726240000,
#      'departure': 1736726240000,
#      'vertexType': 'TRANSIT'},
#     'to': {'name': 'CLEMENTI MRT STATION',
#      'stopId': 'FERRY:EW23',
#      'stopCode': 'EW23',
#      'lon': 103.7652135,
#      'lat': 1.3151999,
#      'arrival': 1736726336000,
#      'departure': 1736726513000,
#      'vertexType': 'TRANSIT'},
#     'legGeometry': {'points': 'qy_GkrixR@BODWHBDa@LAEM]AC??EKPG\\Q',
#      'length': 13},
#     'steps': [{'distance': 90.41,
#       'relativeDirection': 'DEPART',
#       'streetName': 'path',
#       'absoluteDirection': 'NORTHWEST',
#       'stayOn': False,
#       'area': False,
#       'bogusName': True,
#       'lon': 103.7650078,
#       'lat': 1.3149657,
#       'elevation': '',
#       'walkingBike': False}],
#     'rentedBike': False,
#     'walkingBike': False,
#     'duration': 96},
#    {'startTime': 1736726513000,
#     'endTime': 1736727254000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 8124.66,
#     'generalizedCost': 1669,
#     'pathway': False,
#     'mode': 'SUBWAY',
#     'transitLeg': True,
#     'route': 'EW',
#     'agencyName': 'SMRT Corporation',
#     'agencyUrl': 'http://www.smrt.com.sg/',
#     'agencyTimeZoneOffset': 28800000,
#     'routeType': 1,
#     'routeId': 'EW',
#     'interlineWithPreviousLeg': False,
#     'agencyId': '1:SMRT',
#     'tripId': 'EW-2-1029',
#     'serviceDate': '2025-01-13',
#     'from': {'name': 'CLEMENTI MRT STATION',
#      'stopId': 'FERRY:EW23',
#      'stopCode': 'EW23',
#      'lon': 103.7652135,
#      'lat': 1.3151999,
#      'arrival': 1736726336000,
#      'departure': 1736726513000,
#      'stopIndex': 22,
#      'stopSequence': 23,
#      'vertexType': 'TRANSIT'},
#     'to': {'name': 'BOON LAY MRT STATION',
#      'stopId': 'FERRY:EW27',
#      'stopCode': 'EW27',
#      'lon': 103.7061638,
#      'lat': 1.3386421,
#      'arrival': 1736727254000,
#      'departure': 1736727254000,
#      'stopIndex': 26,
#      'stopSequence': 27,
#      'vertexType': 'TRANSIT'},
#     'intermediateStops': [{'name': 'JURONG EAST MRT STATION',
#       'stopId': 'FERRY:EW24',
#       'stopCode': 'EW24',
#       'lon': 103.7422654,
#       'lat': 1.3330748,
#       'arrival': 1736726793000,
#       'departure': 1736726823000,
#       'stopIndex': 23,
#       'stopSequence': 24,
#       'vertexType': 'TRANSIT'},
#      {'name': 'CHINESE GARDEN MRT STATION',
#       'stopId': 'FERRY:EW25',
#       'stopCode': 'EW25',
#       'lon': 103.7327666,
#       'lat': 1.3422449,
#       'arrival': 1736726942000,
#       'departure': 1736726972000,
#       'stopIndex': 24,
#       'stopSequence': 25,
#       'vertexType': 'TRANSIT'},
#      {'name': 'LAKESIDE MRT STATION',
#       'stopId': 'FERRY:EW26',
#       'stopCode': 'EW26',
#       'lon': 103.7209246,
#       'lat': 1.3442249,
#       'arrival': 1736727083000,
#       'departure': 1736727113000,
#       'stopIndex': 25,
#       'stopSequence': 26,
#       'vertexType': 'TRANSIT'}],
#     'legGeometry': {'points': 'wz_G_sixR{Ah@QFODA?OFODQDC@KBQDC@KDQDODQDODOFE@KBOFOFOFOHGBGBMHOHOHMHOHeRzKKFA@OHMHMFA@OHMHOFOHMFOHOFOFOHOFOFQDA@MDOFOFmMlE?@ODOFQFOFOFGBGBOFMHOHOHMHMJMHMJMJMJKJMJKLKLKLILKLILILINILINGNGNGNGNEPGNENEPCN??EPCPCPCNEPqBzNCL?BCPCNEPALABCPCNEPCPENCPENEPCJABEPENEPYbA?BEJENEPENEPENCPABCLCNCPCPCPANAPCPAPAP?PAN?@?P?P?P?P?P?P?t@?D@J?P?P?P?P?PAP?D?JAPAPAPAPANCPAPCPCPENCPEPCNEPENGPCJABGNENGNGPGNGN{FpNyAnDELA@GNGNGNGNINABEHINILINKLILKLKLKLKJMJKLMJMHMJMJMHOHKFA@OHOFOHOFOHwB`A??A?}OhHEBIDMFOFOHOHOFMHGBGDMHMJOHMJKJMJMJKJKLC@GHKLKLKLKLILKLkGpIABIHINKLILKLILKLILmI~LEFEDILINKLEFCDINGJA@INGNILEJABININGLGJABILIN??KLILINoAhB????gBfCi@z@??KLINILKLINIL??INILGNINGNGNGNGNGNGNENEPENEPENEPCPENCPCPCPANCPAPAPAPAPAP?N?@AP?P?P?P?P?jB?F?H?P?P?P?P?PAF?H?PAPAPCPANCPAL?BCPCPCNEPCPq@|DADCJCPCNEPCP?BCLANCPCPAPAN?@APAF?HAPAP?P?PAP@P?P?P@N@P@P@P@PBP@J@DBPBNBPBPjAfH????zAlJ??BNBPDPBP??DNDP@F@FDPDNFPfExOBF@HDNDNFP@F@FDPDN?BDLBPDNDP?@DLBPDNDP?@DNBNDN?@DNDPFNtEzPDN?@DNDPFNBL@@DPFNDNFNFPDN@@DLFNFNFN~B`GFL?@FNBDBHFNFNHNFNFNFL?@HNBDBHHLFNFNBFBFFNFPDN@@DLDPDNFN\\rA',
#      'length': 491},
#     'steps': [],
#     'routeShortName': 'EW',
#     'routeLongName': 'EAST WEST LINE',
#     'duration': 741},
#    {'startTime': 1736727254000,
#     'endTime': 1736727414000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 176.83,
#     'generalizedCost': 1162,
#     'pathway': False,
#     'mode': 'WALK',
#     'transitLeg': False,
#     'route': '',
#     'agencyTimeZoneOffset': 28800000,
#     'interlineWithPreviousLeg': False,
#     'from': {'name': 'BOON LAY MRT STATION',
#      'stopId': 'FERRY:EW27',
#      'stopCode': 'EW27',
#      'lon': 103.7061638,
#      'lat': 1.3386421,
#      'arrival': 1736727254000,
#      'departure': 1736727254000,
#      'vertexType': 'TRANSIT'},
#     'to': {'name': 'BOON LAY INT',
#      'stopId': 'FERRY:22009',
#      'stopCode': '22009',
#      'lon': 103.705457,
#      'lat': 1.3393233,
#      'arrival': 1736727414000,
#      'departure': 1736727660000,
#      'vertexType': 'TRANSIT'},
#     'legGeometry': {'points': 'omdGob~wR??ZhAa@Jc@J[HJd@aATKY??',
#      'length': 10},
#     'steps': [{'distance': 176.83,
#       'relativeDirection': 'DEPART',
#       'streetName': 'path',
#       'absoluteDirection': 'WEST',
#       'stayOn': False,
#       'area': False,
#       'bogusName': True,
#       'lon': 103.7061638,
#       'lat': 1.3386421,
#       'elevation': '',
#       'walkingBike': False}],
#     'rentedBike': False,
#     'walkingBike': False,
#     'duration': 160},
#    {'startTime': 1736727660000,
#     'endTime': 1736728314000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 3253.13,
#     'generalizedCost': 1553,
#     'pathway': False,
#     'mode': 'BUS',
#     'transitLeg': True,
#     'route': '199',
#     'agencyName': 'SBS Transit',
#     'agencyUrl': 'http://www.sbstransit.com.sg/',
#     'agencyTimeZoneOffset': 28800000,
#     'routeType': 3,
#     'routeId': '199',
#     'interlineWithPreviousLeg': False,
#     'agencyId': '1:SBST',
#     'tripId': '199-1-1018',
#     'serviceDate': '2025-01-13',
#     'from': {'name': 'BOON LAY INT',
#      'stopId': 'FERRY:22009',
#      'stopCode': '22009',
#      'lon': 103.705457,
#      'lat': 1.3393233,
#      'arrival': 1736727414000,
#      'departure': 1736727660000,
#      'stopIndex': 0,
#      'stopSequence': 1,
#      'vertexType': 'TRANSIT'},
#     'to': {'name': 'BEF LOR DANAU',
#      'stopId': 'FERRY:27171',
#      'stopCode': '27171',
#      'lon': 103.6916825,
#      'lat': 1.3560457,
#      'arrival': 1736728314000,
#      'departure': 1736728314000,
#      'stopIndex': 6,
#      'stopSequence': 7,
#      'vertexType': 'TRANSIT'},
#     'intermediateStops': [{'name': 'BLK 683A',
#       'stopId': 'FERRY:22489',
#       'stopCode': '22489',
#       'lon': 103.7053683,
#       'lat': 1.3425846,
#       'arrival': 1736727790000,
#       'departure': 1736727820000,
#       'stopIndex': 1,
#       'stopSequence': 2,
#       'vertexType': 'TRANSIT'},
#      {'name': 'BLK 680C',
#       'stopId': 'FERRY:21371',
#       'stopCode': '21371',
#       'lon': 103.7061787,
#       'lat': 1.3452272,
#       'arrival': 1736727892000,
#       'departure': 1736727922000,
#       'stopIndex': 2,
#       'stopSequence': 3,
#       'vertexType': 'TRANSIT'},
#      {'name': 'OPP BLK 271 CP',
#       'stopId': 'FERRY:27091',
#       'stopCode': '27091',
#       'lon': 103.703885,
#       'lat': 1.34911,
#       'arrival': 1736727994000,
#       'departure': 1736728024000,
#       'stopIndex': 3,
#       'stopSequence': 4,
#       'vertexType': 'TRANSIT'},
#      {'name': 'OPP WESTWOOD SEC SCH',
#       'stopId': 'FERRY:27101',
#       'stopCode': '27101',
#       'lon': 103.7011164,
#       'lat': 1.3525947,
#       'arrival': 1736728096000,
#       'departure': 1736728126000,
#       'stopIndex': 4,
#       'stopSequence': 5,
#       'vertexType': 'TRANSIT'},
#      {'name': 'BEF NANYANG AVE',
#       'stopId': 'FERRY:27121',
#       'stopCode': '27121',
#       'lon': 103.6952128,
#       'lat': 1.3568231,
#       'arrival': 1736728226000,
#       'departure': 1736728256000,
#       'stopIndex': 5,
#       'stopSequence': 6,
#       'vertexType': 'TRANSIT'}],
#     'legGeometry': {'points': '{wdGg~}wRhAfEJ^Nj@??BJG?}@F_@Bo@DO@]BSBU@A?K@CYIy@Ei@Qs@O[UWg@UaAWOEGAcAWQEKA??k@Ok@UWUq@iAOYYc@u@oAw@]eA@qCbBE@GDEBKF????IDeEhCe@XIDWNq@b@KFA@OHQL_Af@qErBmBx@????_EdBEBe@Ru@ZUJSJa@Ri@\\}@l@WTuAzA{BnD????{@tAqClEQVyCzEu@jA]`@?@KJINsA`CaAfBo@dAk@z@EDy@dAy@v@????UTOb@Ep@t@xABH`BbD\\|@Nb@RbB@rAALE\\ADAHCH',
#      'length': 108},
#     'steps': [],
#     'routeShortName': '199',
#     'routeLongName': 'SBST BUS 199',
#     'duration': 654},
#    {'startTime': 1736728314000,
#     'endTime': 1736728345000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 31.91,
#     'generalizedCost': 213,
#     'pathway': False,
#     'mode': 'WALK',
#     'transitLeg': False,
#     'route': '',
#     'agencyTimeZoneOffset': 28800000,
#     'interlineWithPreviousLeg': False,
#     'from': {'name': 'BEF LOR DANAU',
#      'stopId': 'FERRY:27171',
#      'stopCode': '27171',
#      'lon': 103.6916825,
#      'lat': 1.3560457,
#      'arrival': 1736728314000,
#      'departure': 1736728314000,
#      'vertexType': 'TRANSIT'},
#     'to': {'name': 'Destination',
#      'lon': 103.691928,
#      'lat': 1.355851,
#      'arrival': 1736728345000,
#      'vertexType': 'NORMAL'},
#     'legGeometry': {'points': 'gzgG_h{wR??C?Fa@@Q', 'length': 5},
#     'steps': [{'distance': 31.91,
#       'relativeDirection': 'DEPART',
#       'streetName': 'path',
#       'absoluteDirection': 'NORTH',
#       'stayOn': False,
#       'area': False,
#       'bogusName': True,
#       'lon': 103.6916825,
#       'lat': 1.3560456,
#       'elevation': '',
#       'walkingBike': False}],
#     'rentedBike': False,
#     'walkingBike': False,
#     'duration': 31}],
#   'tooSloped': False,
#   'arrivedAtDestinationWithRentedBicycle': False},
#  {'duration': 3275,
#   'startTime': 1736725070000,
#   'endTime': 1736728345000,
#   'walkTime': 477,
#   'transitTime': 2253,
#   'waitingTime': 545,
#   'walkDistance': 490.29,
#   'walkLimitExceeded': False,
#   'generalizedCost': 7968,
#   'elevationLost': 0,
#   'elevationGained': 0,
#   'transfers': 2,
#   'fare': '2.10',
#   'legs': [{'startTime': 1736725070000,
#     'endTime': 1736725205000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 137.01,
#     'generalizedCost': 910,
#     'pathway': False,
#     'mode': 'WALK',
#     'transitLeg': False,
#     'route': '',
#     'agencyTimeZoneOffset': 28800000,
#     'interlineWithPreviousLeg': False,
#     'from': {'name': 'Origin',
#      'lon': 103.777154,
#      'lat': 1.297506,
#      'departure': 1736725070000,
#      'vertexType': 'NORMAL'},
#     'to': {'name': 'OPP UNIVERSITY HALL',
#      'stopId': 'FERRY:18319',
#      'stopCode': '18319',
#      'lon': 103.7781311,
#      'lat': 1.2975264,
#      'arrival': 1736725205000,
#      'departure': 1736725205000,
#      'vertexType': 'TRANSIT'},
#     'legGeometry': {'points': 'kl|Fe~kxROECI@I[QJUJWOIJWBYBMJ_@@?',
#      'length': 13},
#     'steps': [{'distance': 137.01,
#       'relativeDirection': 'DEPART',
#       'streetName': 'path',
#       'absoluteDirection': 'NORTHEAST',
#       'stayOn': False,
#       'area': False,
#       'bogusName': True,
#       'lon': 103.7771582,
#       'lat': 1.2975045,
#       'elevation': '',
#       'walkingBike': False}],
#     'rentedBike': False,
#     'walkingBike': False,
#     'duration': 135},
#    {'startTime': 1736725205000,
#     'endTime': 1736725758000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 2767.8,
#     'generalizedCost': 1145,
#     'pathway': False,
#     'mode': 'BUS',
#     'transitLeg': True,
#     'route': '95',
#     'agencyName': 'SBS Transit',
#     'agencyUrl': 'http://www.sbstransit.com.sg/',
#     'agencyTimeZoneOffset': 28800000,
#     'routeType': 3,
#     'routeId': '95',
#     'interlineWithPreviousLeg': False,
#     'agencyId': '1:SBST',
#     'tripId': '95-1-1008',
#     'serviceDate': '2025-01-13',
#     'from': {'name': 'OPP UNIVERSITY HALL',
#      'stopId': 'FERRY:18319',
#      'stopCode': '18319',
#      'lon': 103.7781311,
#      'lat': 1.2975264,
#      'arrival': 1736725205000,
#      'departure': 1736725205000,
#      'stopIndex': 5,
#      'stopSequence': 6,
#      'vertexType': 'TRANSIT'},
#     'to': {'name': 'BUONA VISTA STN EXIT C',
#      'stopId': 'FERRY:11361',
#      'stopCode': '11361',
#      'lon': 103.7905812,
#      'lat': 1.306497,
#      'arrival': 1736725758000,
#      'departure': 1736725758000,
#      'stopIndex': 11,
#      'stopSequence': 12,
#      'vertexType': 'TRANSIT'},
#     'intermediateStops': [{'name': 'BLK S17',
#       'stopId': 'FERRY:18309',
#       'stopCode': '18309',
#       'lon': 103.781342,
#       'lat': 1.2975201,
#       'arrival': 1736725248000,
#       'departure': 1736725278000,
#       'stopIndex': 6,
#       'stopSequence': 7,
#       'vertexType': 'TRANSIT'},
#      {'name': 'OPP NUH',
#       'stopId': 'FERRY:18239',
#       'stopCode': '18239',
#       'lon': 103.7831878,
#       'lat': 1.2967894,
#       'arrival': 1736725321000,
#       'departure': 1736725351000,
#       'stopIndex': 7,
#       'stopSequence': 8,
#       'vertexType': 'TRANSIT'},
#      {'name': 'OPP KENT RIDGE STN EXIT A',
#       'stopId': 'FERRY:18339',
#       'stopCode': '18339',
#       'lon': 103.7850791,
#       'lat': 1.293793,
#       'arrival': 1736725394000,
#       'departure': 1736725424000,
#       'stopIndex': 8,
#       'stopSequence': 9,
#       'vertexType': 'TRANSIT'},
#      {'name': 'OPP AYER RAJAH IND EST',
#       'stopId': 'FERRY:18121',
#       'stopCode': '18121',
#       'lon': 103.7854209,
#       'lat': 1.2975117,
#       'arrival': 1736725525000,
#       'departure': 1736725555000,
#       'stopIndex': 9,
#       'stopSequence': 10,
#       'vertexType': 'TRANSIT'},
#      {'name': 'AFT ANGLO-CHINESE JC',
#       'stopId': 'FERRY:18141',
#       'stopCode': '18141',
#       'lon': 103.7878809,
#       'lat': 1.3041828,
#       'arrival': 1736725670000,
#       'departure': 1736725700000,
#       'stopIndex': 10,
#       'stopSequence': 11,
#       'vertexType': 'TRANSIT'}],
#     'legGeometry': {'points': 'cl|FcdlxR??BMPm@b@_BLg@?m@Gk@Ma@Uw@SmAAe@GmB?A@a@?E?C?????CDSBMDOJQX_@R[Rc@?GHiANcAPSLQ????Za@\\a@DEJMn@a@nCsAfAm@`CeBDA^IjAE????J?`@IVMTULKmAu@o@]AA??A?u@Qc@Ea@CS?i@@g@H_ADU@Q?u@DcENA???A?g@EeAHa@F????A?a@FE?iBVs@Du@AO?g@C_@GC?AAA?A?A?A?MCKC??A?EAEAUE]KWIeCsAeCeBUM_@QQGOGKEC?EAMCA???o@Ka@Gy@KC?WEuAa@SK[MCA??A???ECCC??A?EEWUOKi@a@[a@AA????AACCkAwBCE??AEGKoBgDy@kACECEe@Uy@o@A?AAA?e@Yu@Y??AA??A?AACA',
#      'length': 160},
#     'steps': [],
#     'routeShortName': '95',
#     'routeLongName': 'SBST BUS 95',
#     'duration': 553},
#    {'startTime': 1736725758000,
#     'endTime': 1736725909000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 144.54,
#     'generalizedCost': 962,
#     'pathway': False,
#     'mode': 'WALK',
#     'transitLeg': False,
#     'route': '',
#     'agencyTimeZoneOffset': 28800000,
#     'interlineWithPreviousLeg': False,
#     'from': {'name': 'BUONA VISTA STN EXIT C',
#      'stopId': 'FERRY:11361',
#      'stopCode': '11361',
#      'lon': 103.7905812,
#      'lat': 1.306497,
#      'arrival': 1736725758000,
#      'departure': 1736725758000,
#      'vertexType': 'TRANSIT'},
#     'to': {'name': 'BUONA VISTA MRT STATION',
#      'stopId': 'FERRY:EW21',
#      'stopCode': 'EW21',
#      'lon': 103.790017,
#      'lat': 1.3072658,
#      'arrival': 1736725909000,
#      'departure': 1736726208000,
#      'vertexType': 'TRANSIT'},
#     'legGeometry': {'points': 'qd~FcrnxR??GDAACDCAGEA?IFE@G?qAIE`@MjA?@??',
#      'length': 16},
#     'steps': [{'distance': 144.54,
#       'relativeDirection': 'DEPART',
#       'streetName': 'path',
#       'absoluteDirection': 'NORTHWEST',
#       'stayOn': False,
#       'area': False,
#       'bogusName': True,
#       'lon': 103.7905825,
#       'lat': 1.3064977,
#       'elevation': '',
#       'walkingBike': False}],
#     'rentedBike': False,
#     'walkingBike': False,
#     'duration': 151},
#    {'startTime': 1736726208000,
#     'endTime': 1736727254000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 11211.73,
#     'generalizedCost': 2096,
#     'pathway': False,
#     'mode': 'SUBWAY',
#     'transitLeg': True,
#     'route': 'EW',
#     'agencyName': 'SMRT Corporation',
#     'agencyUrl': 'http://www.smrt.com.sg/',
#     'agencyTimeZoneOffset': 28800000,
#     'routeType': 1,
#     'routeId': 'EW',
#     'interlineWithPreviousLeg': False,
#     'agencyId': '1:SMRT',
#     'tripId': 'EW-2-1029',
#     'serviceDate': '2025-01-13',
#     'from': {'name': 'BUONA VISTA MRT STATION',
#      'stopId': 'FERRY:EW21',
#      'stopCode': 'EW21',
#      'lon': 103.790017,
#      'lat': 1.3072658,
#      'arrival': 1736725909000,
#      'departure': 1736726208000,
#      'stopIndex': 20,
#      'stopSequence': 21,
#      'vertexType': 'TRANSIT'},
#     'to': {'name': 'BOON LAY MRT STATION',
#      'stopId': 'FERRY:EW27',
#      'stopCode': 'EW27',
#      'lon': 103.7061638,
#      'lat': 1.3386421,
#      'arrival': 1736727254000,
#      'departure': 1736727254000,
#      'stopIndex': 26,
#      'stopSequence': 27,
#      'vertexType': 'TRANSIT'},
#     'intermediateStops': [{'name': 'DOVER MRT STATION',
#       'stopId': 'FERRY:EW22',
#       'stopCode': 'EW22',
#       'lon': 103.7785844,
#       'lat': 1.3114548,
#       'arrival': 1736726318000,
#       'departure': 1736726348000,
#       'stopIndex': 21,
#       'stopSequence': 22,
#       'vertexType': 'TRANSIT'},
#      {'name': 'CLEMENTI MRT STATION',
P?P?P?P?P?jB?F?H?P?P?P?P?PAF?H?PAPAPCPANCPAL?BCPCPCNEPCPq@|DADCJCPCNEPCP?BCLANCPCPAPAN?@APAF?HAPAP?P?PAP@P?P?P@N@P@P@P@PBP@J@DBPBNBPBPjAfH????zAlJ??BNBPDPBP??DNDP@F@FDPDNFPfExOBF@HDNDNFP@F@FDPDN?BDLBPDNDP?@DLBPDNDP?@DNBNDN?@DNDPFNtEzPDN?@DNDPFNBL@@DPFNDNFNFPDN@@DLFNFNFN~B`GFL?@FNBDBHFNFNHNFNFNFL?@HNBDBHHLFNFNBFBFFNFPDN@@DLDPDNFN\\rA',
#      'length': 625},
#     'steps': [],
#     'routeShortName': 'EW',
#     'routeLongName': 'EAST WEST LINE',
#     'duration': 1046},
#    {'startTime': 1736727254000,
#     'endTime': 1736727414000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 176.83,
#     'generalizedCost': 1162,
#     'pathway': False,
#     'mode': 'WALK',
#     'transitLeg': False,
#     'route': '',
#     'agencyTimeZoneOffset': 28800000,
#     'interlineWithPreviousLeg': False,
#     'from': {'name': 'BOON LAY MRT STATION',
#      'stopId': 'FERRY:EW27',
#      'stopCode': 'EW27',
#      'lon': 103.7061638,
#      'lat': 1.3386421,
#      'arrival': 1736727254000,
#      'departure': 1736727254000,
#      'vertexType': 'TRANSIT'},
#     'to': {'name': 'BOON LAY INT',
#      'stopId': 'FERRY:22009',
#      'stopCode': '22009',
#      'lon': 103.705457,
#      'lat': 1.3393233,
#      'arrival': 1736727414000,
#      'departure': 1736727660000,
#      'vertexType': 'TRANSIT'},
#     'legGeometry': {'points': 'omdGob~wR??ZhAa@Jc@J[HJd@aATKY??',
#      'length': 10},
#     'steps': [{'distance': 176.83,
#       'relativeDirection': 'DEPART',
#       'streetName': 'path',
#       'absoluteDirection': 'WEST',
#       'stayOn': False,
#       'area': False,
#       'bogusName': True,
#       'lon': 103.7061638,
#       'lat': 1.3386421,
#       'elevation': '',
#       'walkingBike': False}],
#     'rentedBike': False,
#     'walkingBike': False,
#     'duration': 160},
#    {'startTime': 1736727660000,
#     'endTime': 1736728314000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 3253.13,
#     'generalizedCost': 1553,
#     'pathway': False,
#     'mode': 'BUS',
#     'transitLeg': True,
#     'route': '199',
#     'agencyName': 'SBS Transit',
#     'agencyUrl': 'http://www.sbstransit.com.sg/',
#     'agencyTimeZoneOffset': 28800000,
#     'routeType': 3,
#     'routeId': '199',
#     'interlineWithPreviousLeg': False,
#     'agencyId': '1:SBST',
#     'tripId': '199-1-1018',
#     'serviceDate': '2025-01-13',
#     'from': {'name': 'BOON LAY INT',
#      'stopId': 'FERRY:22009',
#      'stopCode': '22009',
#      'lon': 103.705457,
#      'lat': 1.3393233,
#      'arrival': 1736727414000,
#      'departure': 1736727660000,
#      'stopIndex': 0,
#      'stopSequence': 1,
#      'vertexType': 'TRANSIT'},
#     'to': {'name': 'BEF LOR DANAU',
#      'stopId': 'FERRY:27171',
#      'stopCode': '27171',
#      'lon': 103.6916825,
#      'lat': 1.3560457,
#      'arrival': 1736728314000,
#      'departure': 1736728314000,
#      'stopIndex': 6,
#      'stopSequence': 7,
#      'vertexType': 'TRANSIT'},
#     'intermediateStops': [{'name': 'BLK 683A',
#       'stopId': 'FERRY:22489',
#       'stopCode': '22489',
#       'lon': 103.7053683,
#       'lat': 1.3425846,
#       'arrival': 1736727790000,
#       'departure': 1736727820000,
#       'stopIndex': 1,
#       'stopSequence': 2,
#       'vertexType': 'TRANSIT'},
#      {'name': 'BLK 680C',
#       'stopId': 'FERRY:21371',
#       'stopCode': '21371',
#       'lon': 103.7061787,
#       'lat': 1.3452272,
#       'arrival': 1736727892000,
#       'departure': 1736727922000,
#       'stopIndex': 2,
#       'stopSequence': 3,
#       'vertexType': 'TRANSIT'},
#      {'name': 'OPP BLK 271 CP',
#       'stopId': 'FERRY:27091',
#       'stopCode': '27091',
#       'lon': 103.703885,
#       'lat': 1.34911,
#       'arrival': 1736727994000,
#       'departure': 1736728024000,
#       'stopIndex': 3,
#       'stopSequence': 4,
#       'vertexType': 'TRANSIT'},
#      {'name': 'OPP WESTWOOD SEC SCH',
#       'stopId': 'FERRY:27101',
#       'stopCode': '27101',
#       'lon': 103.7011164,
#       'lat': 1.3525947,
#       'arrival': 1736728096000,
#       'departure': 1736728126000,
#       'stopIndex': 4,
#       'stopSequence': 5,
#       'vertexType': 'TRANSIT'},
#      {'name': 'BEF NANYANG AVE',
#       'stopId': 'FERRY:27121',
#       'stopCode': '27121',
#       'lon': 103.6952128,
#       'lat': 1.3568231,
#       'arrival': 1736728226000,
#       'departure': 1736728256000,
#       'stopIndex': 5,
#       'stopSequence': 6,
#       'vertexType': 'TRANSIT'}],
#     'legGeometry': {'points': '{wdGg~}wRhAfEJ^Nj@??BJG?}@F_@Bo@DO@]BSBU@A?K@CYIy@Ei@Qs@O[UWg@UaAWOEGAcAWQEKA??k@Ok@UWUq@iAOYYc@u@oAw@]eA@qCbBE@GDEBKF????IDeEhCe@XIDWNq@b@KFA@OHQL_Af@qErBmBx@????_EdBEBe@Ru@ZUJSJa@Ri@\\}@l@WTuAzA{BnD????{@tAqClEQVyCzEu@jA]`@?@KJINsA`CaAfBo@dAk@z@EDy@dAy@v@????UTOb@Ep@t@xABH`BbD\\|@Nb@RbB@rAALE\\ADAHCH',
#      'length': 108},
#     'steps': [],
#     'routeShortName': '199',
#     'routeLongName': 'SBST BUS 199',
#     'duration': 654},
#    {'startTime': 1736728314000,
#     'endTime': 1736728345000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 31.91,
#     'generalizedCost': 213,
#     'pathway': False,
#     'mode': 'WALK',
#     'transitLeg': False,
#     'route': '',
#     'agencyTimeZoneOffset': 28800000,
#     'interlineWithPreviousLeg': False,
#     'from': {'name': 'BEF LOR DANAU',
#      'stopId': 'FERRY:27171',
#      'stopCode': '27171',
#      'lon': 103.6916825,
#      'lat': 1.3560457,
#      'arrival': 1736728314000,
#      'departure': 1736728314000,
#      'vertexType': 'TRANSIT'},
#     'to': {'name': 'Destination',
#      'lon': 103.691928,
#      'lat': 1.355851,
#      'arrival': 1736728345000,
#      'vertexType': 'NORMAL'},
#     'legGeometry': {'points': 'gzgG_h{wR??C?Fa@@Q', 'length': 5},
#     'steps': [{'distance': 31.91,
#       'relativeDirection': 'DEPART',
#       'streetName': 'path',
#       'absoluteDirection': 'NORTH',
#       'stayOn': False,
#       'area': False,
#       'bogusName': True,
#       'lon': 103.6916825,
#       'lat': 1.3560456,
#       'elevation': '',
#       'walkingBike': False}],
#     'rentedBike': False,
#     'walkingBike': False,
#     'duration': 31}],
#   'tooSloped': False,
#   'arrivedAtDestinationWithRentedBicycle': False},
#  {'duration': 4056,
#   'startTime': 1736724919000,
#   'endTime': 1736728975000,
#   'walkTime': 444,
#   'transitTime': 3307,
#   'waitingTime': 305,
#   'walkDistance': 487.11,
#   'walkLimitExceeded': False,
#   'generalizedCost': 7671,
#   'elevationLost': 0,
#   'elevationGained': 0,
#   'transfers': 1,
#   'fare': '2.06',
#   'legs': [{'startTime': 1736724919000,
#     'endTime': 1736725332000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 455.2,
#     'generalizedCost': 2990,
#     'pathway': False,
#     'mode': 'WALK',
#     'transitLeg': False,
#     'route': '',
#     'agencyTimeZoneOffset': 28800000,
#     'interlineWithPreviousLeg': False,
#     'from': {'name': 'Origin',
#      'lon': 103.777154,
#      'lat': 1.297506,
#      'departure': 1736724919000,
#      'vertexType': 'NORMAL'},
#     'to': {'name': 'OPP SIT DOVER',
#      'stopId': 'FERRY:16091',
#      'stopCode': '16091',
#      'lon': 103.7793712,
#      'lat': 1.2992747,
#      'arrival': 1736725332000,
#      'departure': 1736725332000,
#      'vertexType': 'TRANSIT'},
#     'legGeometry': {'points': 'kl|Fe~kxROECI@I[QJUJWOIJWBYBMJ_@??P]Ng@]I]KWG@E_Bg@uDLBOAUI[?KIEOIJU',
#      'length': 28},
#     'steps': [{'distance': 455.2,
#       'relativeDirection': 'DEPART',
#       'streetName': 'path',
#       'absoluteDirection': 'NORTHEAST',
#       'stayOn': False,
#       'area': False,
#       'bogusName': True,
#       'lon': 103.7771582,
#       'lat': 1.2975045,
#       'elevation': '',
#       'walkingBike': False}],
#     'rentedBike': False,
#     'walkingBike': False,
#     'duration': 413},
#    {'startTime': 1736725332000,
#     'endTime': 1736727985000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 12679.71,
#     'generalizedCost': 2930,
#     'pathway': False,
#     'mode': 'BUS',
#     'transitLeg': True,
#     'route': '198',
#     'agencyName': 'SBS Transit',
#     'agencyUrl': 'http://www.sbstransit.com.sg/',
#     'agencyTimeZoneOffset': 28800000,
#     'routeType': 3,
#     'routeId': '198',
#     'interlineWithPreviousLeg': False,
#     'agencyId': '1:SBST',
#     'tripId': '198-2-1007',
#     'serviceDate': '2025-01-13',
#     'from': {'name': 'OPP SIT DOVER',
#      'stopId': 'FERRY:16091',
#      'stopCode': '16091',
#      'lon': 103.7793712,
#      'lat': 1.2992747,
#      'arrival': 1736725332000,
#      'departure': 1736725332000,
#      'stopIndex': 15,
#      'stopSequence': 16,
#      'vertexType': 'TRANSIT'},
#     'to': {'name': 'BOON LAY INT',
#      'stopId': 'FERRY:22009',
#      'stopCode': '22009',
#      'lon': 103.705457,
#      'lat': 1.3393233,
#      'arrival': 1736727985000,
#      'departure': 1736728290000,
#      'stopIndex': 43,
#      'stopSequence': 44,
#      'vertexType': 'TRANSIT'},
#     'intermediateStops': [{'name': 'BLK 610',
#       'stopId': 'FERRY:17121',
#       'stopCode': '17121',
#       'lon': 103.7694454,
#       'lat': 1.3047641,
#       'arrival': 1736725519000,
#       'departure': 1736725549000,
#       'stopIndex': 16,
#       'stopSequence': 17,
#       'vertexType': 'TRANSIT'},
#      {'name': 'CLEMENTI FLYOVER',
#       'stopId': 'FERRY:17131',
#       'stopCode': '17131',
#       'lon': 103.7660121,
#       'lat': 1.3081769,
#       'arrival': 1736725621000,
#       'departure': 1736725651000,
#       'stopIndex': 17,
#       'stopSequence': 18,
#       'vertexType': 'TRANSIT'},
#      {'name': 'CLEMENTI STADIUM',
#       'stopId': 'FERRY:17141',
#       'stopCode': '17141',
#       'lon': 103.7635,
#       'lat': 1.310995,
#       'arrival': 1736725709000,
#       'departure': 1736725739000,
#       'stopIndex': 18,
#       'stopSequence': 19,
#       'vertexType': 'TRANSIT'},
#      {'name': 'BLK 506',
#       'stopId': 'FERRY:20011',
#       'stopCode': '20011',
#       'lon': 103.7612873,
#       'lat': 1.3130862,
#       'arrival': 1736725796000,
#       'departure': 1736725826000,
#       'stopIndex': 19,
#       'stopSequence': 20,
#       'vertexType': 'TRANSIT'},
#      {'name': 'NEWEST',
#       'stopId': 'FERRY:20021',
#       'stopCode': '20021',
#       'lon': 103.7578896,
#       'lat': 1.3167592,
#       'arrival': 1736725898000,
#       'departure': 1736725928000,
#       'stopIndex': 20,
#       'stopSequence': 21,
#       'vertexType': 'TRANSIT'},
#      {'name': 'THE INFINITI',
#       'stopId': 'FERRY:20031',
#       'stopCode': '20031',
#       'lon': 103.7546468,
#       'lat': 1.3205599,
#       'arrival': 1736726000000,
#       'departure': 1736726030000,
#       'stopIndex': 21,
#       'stopSequence': 22,
#       'vertexType': 'TRANSIT'},
#      {'name': 'CYCLE & CARRIAGE',
#       'stopId': 'FERRY:20051',
#       'stopCode': '20051',
#       'lon': 103.7475443,
#       'lat': 1.3225871,
#       'arrival': 1736726146000,
#       'departure': 1736726176000,
#       'stopIndex': 22,
#       'stopSequence': 23,
#       'vertexType': 'TRANSIT'},
#      {'name': 'OPP GERMAN CTR',
#       'stopId': 'FERRY:20271',
#       'stopCode': '20271',
#       'lon': 103.7455089,
#       'lat': 1.3252755,
#       'arrival': 1736726248000,
#       'departure': 1736726278000,
#       'stopIndex': 23,
#       'stopSequence': 24,
#       'vertexType': 'TRANSIT'},
#      {'name': 'OPP INTL BUSINESS PK',
#       'stopId': 'FERRY:28221',
#       'stopCode': '28221',
#       'lon': 103.7449417,
#       'lat': 1.3276181,
#       'arrival': 1736726321000,
#       'departure': 1736726351000,
#       'stopIndex': 24,
#       'stopSequence': 25,
#       'vertexType': 'TRANSIT'},
#      {'name': 'JURONG TOWN HALL',
#       'stopId': 'FERRY:28231',
#       'stopCode': '28231',
#       'lon': 103.7424818,
#       'lat': 1.329862,
#       'arrival': 1736726394000,
#       'departure': 1736726424000,
#       'stopIndex': 25,
#       'stopSequence': 26,
#       'vertexType': 'TRANSIT'},
#      {'name': 'OPP JURONG EAST LIB',
#       'stopId': 'FERRY:28241',
#       'stopCode': '28241',
#       'lon': 103.7395749,
#       'lat': 1.3317586,
#       'arrival': 1736726482000,
#       'departure': 1736726512000,
#       'stopIndex': 26,
#       'stopSequence': 27,
#       'vertexType': 'TRANSIT'},
#      {'name': "S'PORE SCIENCE CTR",
#       'stopId': 'FERRY:28251',
#       'stopCode': '28251',
#       'lon': 103.7369883,
#       'lat': 1.3338281,
#       'arrival': 1736726569000,
#       'departure': 1736726599000,
#       'stopIndex': 27,
#       'stopSequence': 28,
#       'vertexType': 'TRANSIT'},
#      {'name': "AFT S'PORE SCIENCE CTR",
#       'stopId': 'FERRY:28261',
#       'stopCode': '28261',
#       'lon': 103.7348988,
#       'lat': 1.3361424,
#       'arrival': 1736726642000,
#       'departure': 1736726672000,
#       'stopIndex': 28,
#       'stopSequence': 29,
#       'vertexType': 'TRANSIT'},
#      {'name': 'OPP BLK 114',
#       'stopId': 'FERRY:28271',
#       'stopCode': '28271',
#       'lon': 103.7339058,
#       'lat': 1.3389926,
#       'arrival': 1736726730000,
#       'departure': 1736726760000,
#       'stopIndex': 29,
#       'stopSequence': 30,
#       'vertexType': 'TRANSIT'},
#      {'name': 'OPP BLK 227',
#       'stopId': 'FERRY:28281',
#       'stopCode': '28281',
#       'lon': 103.7353755,
#       'lat': 1.3420603,
#       'arrival': 1736726803000,
#       'departure': 1736726833000,
#       'stopIndex': 30,
#       'stopSequence': 31,
#       'vertexType': 'TRANSIT'},
#      {'name': 'PARC OASIS',
#       'stopId': 'FERRY:28451',
#       'stopCode': '28451',
#       'lon': 103.73466,
#       'lat': 1.3439419,
#       'arrival': 1736726876000,
#       'departure': 1736726906000,
#       'stopIndex': 31,
#       'stopSequence': 32,
#       'vertexType': 'TRANSIT'},
#      {'name': 'BLK 347',
#       'stopId': 'FERRY:28461',
#       'stopCode': '28461',
#       'lon': 103.7320538,
#       'lat': 1.3453324,
#       'arrival': 1736726964000,
#       'departure': 1736726994000,
#       'stopIndex': 32,
#       'stopSequence': 33,
#       'vertexType': 'TRANSIT'},
#      {'name': 'OPP JURONG POLYCLINIC',
#       'stopId': 'FERRY:28491',
#       'stopCode': '28491',
#       'lon': 103.7307863,
#       'lat': 1.349056,
#       'arrival': 1736727066000,
#       'departure': 1736727096000,
#       'stopIndex': 33,
#       'stopSequence': 34,
#       'vertexType': 'TRANSIT'},
#      {'name': 'BLK 490',
#       'stopId': 'FERRY:28501',
#       'stopCode': '28501',
#       'lon': 103.7273777,
#       'lat': 1.3498033,
#       'arrival': 1736727154000,
#       'departure': 1736727184000,
#       'stopIndex': 34,
#       'stopSequence': 35,
#       'vertexType': 'TRANSIT'},
#      {'name': 'BLK 463',
#       'stopId': 'FERRY:28511',
#       'stopCode': '28511',
#       'lon': 103.7237236,
#       'lat': 1.350636,
#       'arrival': 1736727241000,
#       'departure': 1736727271000,
#       'stopIndex': 35,
#       'stopSequence': 36,
#       'vertexType': 'TRANSIT'},
#      {'name': 'BLK 457',
#       'stopId': 'FERRY:28521',
#       'stopCode': '28521',
#       'lon': 103.7212004,
#       'lat': 1.3509755,
#       'arrival': 1736727314000,
#       'departure': 1736727344000,
#       'stopIndex': 36,
#       'stopSequence': 37,
#       'vertexType': 'TRANSIT'},
#      {'name': 'BLK 502',
#       'stopId': 'FERRY:28401',
#       'stopCode': '28401',
#       'lon': 103.718614,
#       'lat': 1.3506546,
#       'arrival': 1736727388000,
#       'departure': 1736727418000,
#       'stopIndex': 37,
#       'stopSequence': 38,
#       'vertexType': 'TRANSIT'},
#      {'name': 'BLK 536',
#       'stopId': 'FERRY:28531',
#       'stopCode': '28531',
#       'lon': 103.7165294,
#       'lat': 1.3500612,
#       'arrival': 1736727461000,
#       'departure': 1736727491000,
#       'stopIndex': 38,
#       'stopSequence': 39,
#       'vertexType': 'TRANSIT'},
#      {'name': 'BLK 213',
#       'stopId': 'FERRY:21249',
#       'stopCode': '21249',
#       'lon': 103.7124646,
#       'lat': 1.3495985,
#       'arrival': 1736727577000,
#       'departure': 1736727607000,
#       'stopIndex': 39,
#       'stopSequence': 40,
#       'vertexType': 'TRANSIT'},
#      {'name': 'BLK 185',
#       'stopId': 'FERRY:21429',
#       'stopCode': '21429',
#       'lon': 103.7105915,
#       'lat': 1.347402,
#       'arrival': 1736727665000,
#       'departure': 1736727695000,
#       'stopIndex': 40,
#       'stopSequence': 41,
#       'vertexType': 'TRANSIT'},
#      {'name': 'RIVER VALLEY HIGH SCH',
#       'stopId': 'FERRY:21391',
#       'stopCode': '21391',
#       'lon': 103.7084794,
#       'lat': 1.3448506,
#       'arrival': 1736727752000,
#       'departure': 1736727782000,
#       'stopIndex': 41,
#       'stopSequence': 42,
#       'vertexType': 'TRANSIT'},
#      {'name': 'OPP BLK 695',
#       'stopId': 'FERRY:21369',
#       'stopCode': '21369',
#       'lon': 103.7080031,
#       'lat': 1.3430912,
#       'arrival': 1736727826000,
#       'departure': 1736727856000,
#       'stopIndex': 42,
#       'stopSequence': 43,
#       'vertexType': 'TRANSIT'}],
#     'legGeometry': {'points': 'ix|FqllxRGNINKTkBbD_GpLmDnHaEvIyBnFo@lBuAzDsAnCA@??ABO\\oC`E}B`DsA~A{AtAoDzBA?GD??i@ZQJoDfCmDrC{CzCIH????iCfCmCnCm@jAyAxA????CB}A|A_B|AwBtBiHnGwBbB??mBzA_Ar@aAr@{@^iInGwApAs@z@???@??ED}@xAWt@q@tCyBlJ{@rEm@lEg@jIAL??Y~D?t@CxA?TmABe@@oADW?C?y@?q@?aCAW@????A?{DJwARsC|@w@b@?@??o@^c@^MH[XQPQPeApA]\\{@hAcBhC]f@??}DjGQVSb@S`@cA~AmApB???@CB_ExGU`@i@p@A?ILMLc@f@]d@k@n@??A@c@h@wAvAyDdDsBzA]P????A@yAx@sAn@qAf@gB`@yAJgB@A?????A?mBOgB_@oAg@i@]u@e@QMOIgAs@k@_@o@]CA?A??e@U_Bk@g@@E?c@?c@DYLA?k@^sAzCGLA@???@}@nBk@hBu@xC]t@Y^MPk@d@????MLu@`@w@ViAPgHt@aAN{@Pw@Zs@b@OJCD????YVC@c@l@[l@CFWn@SbAEn@Cl@AzB?R?f@?F?H?h@?\\BpA?B???R?~A?j@SvCiAjEe@hBEN]rA?@??GX_@`CS|BEpACh@@fB?????@?d@ZrEPrCPxB????PhC@BJr@XvA|@hC@@????n@lB\\r@Zl@f@x@h@t@LN?@FFV^PTFHIJQPONUV{DbEzAdC??@Dn@dAxAdCfAbBXT^P^JpC`@????`C\\`AXB@VN^Pt@n@`AxAnB~CJN???@`DlFPITMXQvC}A??@?VO|@e@RMx@e@TMvBwAbCaAb@O\\KHEBJ??HRLd@HZl@`CJRb@~@d@r@_B`AmAb@OJWRGFCZARvAlF`@M',
#      'length': 312},
#     'steps': [],
#     'routeShortName': '198',
#     'routeLongName': 'SBST BUS 198',
#     'duration': 2653},
#    {'startTime': 1736728290000,
#     'endTime': 1736728944000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 3253.13,
#     'generalizedCost': 1612,
#     'pathway': False,
#     'mode': 'BUS',
#     'transitLeg': True,
#     'route': '199',
#     'agencyName': 'SBS Transit',
#     'agencyUrl': 'http://www.sbstransit.com.sg/',
#     'agencyTimeZoneOffset': 28800000,
#     'routeType': 3,
#     'routeId': '199',
#     'interlineWithPreviousLeg': False,
#     'agencyId': '1:SBST',
#     'tripId': '199-1-2001',
#     'serviceDate': '2025-01-13',
#     'from': {'name': 'BOON LAY INT',
#      'stopId': 'FERRY:22009',
#      'stopCode': '22009',
#      'lon': 103.705457,
#      'lat': 1.3393233,
#      'arrival': 1736727985000,
#      'departure': 1736728290000,
#      'stopIndex': 0,
#      'stopSequence': 1,
#      'vertexType': 'TRANSIT'},
#     'to': {'name': 'BEF LOR DANAU',
#      'stopId': 'FERRY:27171',
#      'stopCode': '27171',
#      'lon': 103.6916825,
#      'lat': 1.3560457,
#      'arrival': 1736728944000,
#      'departure': 1736728944000,
#      'stopIndex': 6,
#      'stopSequence': 7,
#      'vertexType': 'TRANSIT'},
#     'intermediateStops': [{'name': 'BLK 683A',
#       'stopId': 'FERRY:22489',
#       'stopCode': '22489',
#       'lon': 103.7053683,
#       'lat': 1.3425846,
#       'arrival': 1736728420000,
#       'departure': 1736728450000,
#       'stopIndex': 1,
#       'stopSequence': 2,
#       'vertexType': 'TRANSIT'},
#      {'name': 'BLK 680C',
#       'stopId': 'FERRY:21371',
#       'stopCode': '21371',
#       'lon': 103.7061787,
#       'lat': 1.3452272,
#       'arrival': 1736728522000,
#       'departure': 1736728552000,
#       'stopIndex': 2,
#       'stopSequence': 3,
#       'vertexType': 'TRANSIT'},
#      {'name': 'OPP BLK 271 CP',
#       'stopId': 'FERRY:27091',
#       'stopCode': '27091',
#       'lon': 103.703885,
#       'lat': 1.34911,
#       'arrival': 1736728624000,
#       'departure': 1736728654000,
#       'stopIndex': 3,
#       'stopSequence': 4,
#       'vertexType': 'TRANSIT'},
#      {'name': 'OPP WESTWOOD SEC SCH',
#       'stopId': 'FERRY:27101',
#       'stopCode': '27101',
#       'lon': 103.7011164,
#       'lat': 1.3525947,
#       'arrival': 1736728726000,
#       'departure': 1736728756000,
#       'stopIndex': 4,
#       'stopSequence': 5,
#       'vertexType': 'TRANSIT'},
#      {'name': 'BEF NANYANG AVE',
#       'stopId': 'FERRY:27121',
#       'stopCode': '27121',
#       'lon': 103.6952128,
#       'lat': 1.3568231,
#       'arrival': 1736728856000,
#       'departure': 1736728886000,
#       'stopIndex': 5,
#       'stopSequence': 6,
#       'vertexType': 'TRANSIT'}],
#     'legGeometry': {'points': '{wdGg~}wRhAfEJ^Nj@??BJG?}@F_@Bo@DO@]BSBU@A?K@CYIy@Ei@Qs@O[UWg@UaAWOEGAcAWQEKA??k@Ok@UWUq@iAOYYc@u@oAw@]eA@qCbBE@GDEBKF????IDeEhCe@XIDWNq@b@KFA@OHQL_Af@qErBmBx@????_EdBEBe@Ru@ZUJSJa@Ri@\\}@l@WTuAzA{BnD????{@tAqClEQVyCzEu@jA]`@?@KJINsA`CaAfBo@dAk@z@EDy@dAy@v@????UTOb@Ep@t@xABH`BbD\\|@Nb@RbB@rAALE\\ADAHCH',
#      'length': 108},
#     'steps': [],
#     'routeShortName': '199',
#     'routeLongName': 'SBST BUS 199',
#     'duration': 654},
#    {'startTime': 1736728944000,
#     'endTime': 1736728975000,
#     'departureDelay': 0,
#     'arrivalDelay': 0,
#     'realTime': False,
#     'distance': 31.91,
#     'generalizedCost': 213,
#     'pathway': False,
#     'mode': 'WALK',
#     'transitLeg': False,
#     'route': '',
#     'agencyTimeZoneOffset': 28800000,
#     'interlineWithPreviousLeg': False,
#     'from': {'name': 'BEF LOR DANAU',
#      'stopId': 'FERRY:27171',
#      'stopCode': '27171',
#      'lon': 103.6916825,
#      'lat': 1.3560457,
#      'arrival': 1736728944000,
#      'departure': 1736728944000,
#      'vertexType': 'TRANSIT'},
#     'to': {'name': 'Destination',
#      'lon': 103.691928,
#      'lat': 1.355851,
#      'arrival': 1736728975000,
#      'vertexType': 'NORMAL'},
#     'legGeometry': {'points': 'gzgG_h{wR??C?Fa@@Q', 'length': 5},
#     'steps': [{'distance': 31.91,
#       'relativeDirection': 'DEPART',
#       'streetName': 'path',
#       'absoluteDirection': 'NORTH',
#       'stayOn': False,
#       'area': False,
#       'bogusName': True,
#       'lon': 103.6916825,
#       'lat': 1.3560456,
#       'elevation': '',
#       'walkingBike': False}],
#     'rentedBike': False,
#     'walkingBike': False,
#     'duration': 31}],
#   'tooSloped': False,
#   'arrivedAtDestinationWithRentedBicycle': False}]

# %% [markdown]
# # Rerun analysis

# %%
save_dir = r"D:\PAKHUIYING\publicTransit_busRouting_busLeg_OneMap"
routes_file = os.path.join(r'data','busRoutingCombinations.txt')
for workplace_ix, workplace_rows in workplace_cluster.iterrows():
    for gtfs_ix, gtfs_rows in GTFS_stops.iterrows():
        # origin coords and origin key
        busStop_coords = (gtfs_rows['stop_lat'],gtfs_rows['stop_lon'])
        busStop_key = gtfs_rows['stop_id']
        # destination coords and destination key
        workplace_coords = (workplace_rows['latitude'], workplace_rows['longitude'])
        workplace_key = int(workplace_rows['node_ID'])
        # save_fp
        save_fp = os.path.join(save_dir,f'{busStop_key}to{workplace_key}.json')
        if not os.path.exists(routes_file):
            with open(routes_file, "w") as myfile:
                myfile.write(f'{save_fp}\n')

        else:
            with open(routes_file, "a") as myfile:
                myfile.write(f'{save_fp}\n')

# %%
busRoutingCombinations = utils.load_txt(os.path.join(r'data','busRoutingCombinations.txt'))
print(len(busRoutingCombinations))
print(busRoutingCombinations[-1])
# Out:
# 63012
# D:\PAKHUIYING\publicTransit_busRouting_busLeg_OneMap\CE0to4602603057.json

# %%
publicTransit_dir = r"D:\PAKHUIYING\publicTransit_busRouting_busLeg_OneMap"
publicTransit_fp_list = [os.path.join(publicTransit_dir,fp) for fp in os.listdir(publicTransit_dir) if not fp.endswith('_ERROR.json')]
print(len(publicTransit_fp_list))
# Out:
# 32265

# %%
additional_analysis_fp = list(set(busRoutingCombinations)^set(publicTransit_fp_list))
additional_analysis_fp = [os.path.splitext(os.path.basename(fp))[0] for fp in additional_analysis_fp]
additional_analysis_fp = [i.split('to') for i in additional_analysis_fp]
print(len(additional_analysis_fp))
additional_analysis_fp[:5]
# Out:
# 30747
# [['16171', '7144522951'],
#  ['21231', '4229611568'],
#  ['59399', '310231673'],
#  ['03339', '4602603057'],
#  ['21169', '7144522951']]

# %%
# fetch new API key
headers = publicTransit.generate_OneMap_token()
# define directories to save
noData_file = os.path.join(r'data','busRoutingError7.txt')
save_dir = r"D:\PAKHUIYING\publicTransit_busRouting_busLeg_OneMap"
# create copies of df
GTFS_stops_copy = GTFS_stops.copy()
GTFS_stops_copy = GTFS_stops_copy.set_index('stop_id')
workplace_cluster_copy = workplace_cluster.copy()
workplace_cluster_copy = workplace_cluster_copy.set_index('node_ID')
for ix,(busStop_key,workplace_key) in enumerate(additional_analysis_fp):
    workplace_key = int(workplace_key)
    # origin coords and origin key
    gtfs_rows = GTFS_stops_copy.loc[busStop_key,:] 
    busStop_coords = (gtfs_rows['stop_lat'],gtfs_rows['stop_lon'])
    # destination coords and destination key
    workplace_rows = workplace_cluster_copy.loc[workplace_key,:]
    workplace_coords = (workplace_rows['latitude'], workplace_rows['longitude'])
    # save_fp
    save_fp = os.path.join(save_dir,f'{busStop_key}to{workplace_key}.json')
    # export data
    try:
        itinerary = publicTransit.public_transit_routing(busStop_coords, busStop_key, 
                            workplace_coords, workplace_key,
                            G_bus, GTFS_shapes, headers,
                            plot = False,
                            busRouteMode='OneMap',
                            save_fp = save_fp)
    except:
        # export data that has an error
        print(f'{ix}:{busStop_key},{ix}:{workplace_key}')
        if not os.path.exists(noData_file):
            with open(noData_file, "w") as myfile:
                myfile.write(f'{ix}:{busStop_key},{ix}:{workplace_key}\n')

        else:
            with open(noData_file, "a") as myfile:
                myfile.write(f'{ix}:{busStop_key},{ix}:{workplace_key}\n')

    # break
# Out:
# Token may have expired, input new headers: 'plan'
# Token may have expired, input new headers: 'plan'
# 389:47151,389:842360753
# Token may have expired, input new headers: 'plan'
# Token may have expired, input new headers: 'plan'
# 431:95049,431:4607055587
# Token may have expired, input new headers: 'plan'
# Token may have expired, input new headers: 'plan'
# 569:46219,569:6247137952
# Shortest path route does not return a list: <class 'NoneType'>
# Token may have expired, input new headers: 'plan'
# Token may have expired, input new headers: 'plan'
# 899:46211,899:4494048581
# Token may have expired, input new headers: 'plan'
# Token may have expired, input new headers: 'plan'
#